# %%
import pandas as pd
import numpy as np
import seaborn as sms
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is AC60-AD3D
#
#  Directory of C:\Users\Lakshmi Priya\OneDrive\Documents\GitHub\Organic-food-tracebality
#
# 07-08-2026  23:33    <DIR>          .
# 27-07-2026  22:30    <DIR>          ..
# 07-08-2026  22:43    <DIR>          .ipynb_checkpoints
# 27-07-2026  23:29                 5 .python-version
# 28-07-2026  22:37    <DIR>          .venv
# 06-08-2026  22:39    <DIR>          __pycache__
# 06-08-2026  22:36             7,335 app.py
# 06-08-2026  20:48    <DIR>          assets
# 03-08-2026  21:45            13,176 cart_page.py
# 07-08-2026  23:33               137 categories.csv
# 06-08-2026  22:41            12,294 categories.ipynb
# 02-08-2026  21:43             2,964 categories.py
# 06-08-2026  22:36             2,526 category_page.py
# 06-08-2026  22:36    <DIR>          components
# 06-08-2026  22:36             1,059 config.py
# 06-08-2026  22:36            26,339 db_manager.py
# ...

# %%
categories = pd.read_csv("categories.csv")

# %%
categories
# Out:
#     CategoryID CategoryName
# 0            1  Confections
# 1            2   Shell fish
# 2            3      Cereals
# 3            4        Dairy
# 4            5    Beverages
# 5            6      Seafood
# 6            7         Meat
# 7            8        Grain
# 8            9      Poultry
# 9           10       Snails
# 10          11      Produce

# %% [raw]
# Fruits
# Vegetables
# Grains
# Pulses
# Dairy
# Spices
# Beverages
# Dry Fruits
# Herbs
# Oils

# %%
categories.loc[categories['CategoryID'] == 1, 'CategoryName'] = 'Fruits'
categories.loc[categories['CategoryID'] == 2, 'CategoryName'] = 'Vegetables'
categories.loc[categories['CategoryID'] == 3, 'CategoryName'] = 'Grains'
categories.loc[categories['CategoryID'] == 4, 'CategoryName'] = 'Pulses'
categories.loc[categories['CategoryID'] == 5, 'CategoryName'] = 'Dairy'
categories.loc[categories['CategoryID'] == 6, 'CategoryName'] = 'Spices'
categories.loc[categories['CategoryID'] == 7, 'CategoryName'] = 'Beverages'
categories.loc[categories['CategoryID'] == 8, 'CategoryName'] = 'Dry Fruits'
categories.loc[categories['CategoryID'] == 9, 'CategoryName'] = 'Millets'
categories.loc[categories['CategoryID'] == 10,'CategoryName'] = 'Oils'

# %%
categories.head(10)
# Out:
#    CategoryID CategoryName
# 0           1       Fruits
# 1           2   Vegetables
# 2           3       Grains
# 3           4       Pulses
# 4           5        Dairy
# 5           6       Spices
# 6           7    Beverages
# 7           8   Dry Fruits
# 8           9      Millets
# 9          10         Oils

# %%
categories=categories.head(10)

# %%
categories.shape
# Out:
# (10, 2)

# %%
categories.to_csv("categories.csv",header=True)
