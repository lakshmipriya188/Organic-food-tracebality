# %%
import pandas as pd
import numpy as np

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in C:\Users\Lakshmi Priya\anaconda3\Lib\site-packages (26.7.0)

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="root123",
    database="farmora"
)

if conn.is_connected():
    print("✅ Successfully connected to Farmora database!")
# Out:
# ✅ Successfully connected to Farmora database!

# %%
customer = pd.read_sql("SELECT * FROM Order_Details", conn)

customer.head()
# Out:
# C:\Users\Lakshmi Priya\AppData\Local\Temp\ipykernel_24044\2017801417.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customer = pd.read_sql("SELECT * FROM Order_Details", conn)
#    order_id  customer_id  product_id  product_count  product_price  \
# 0         6        28663         413              8          95.41
# 1         7        46674         370             12          21.88
# 2        15        19310         134              5          39.85
# 3        16        91867         364             24           8.84
# 4        17        14612         185              4          48.42
#
#    product_discount  price_after_discount  order_date
# 0               5.0                 90.64  2026-02-07
# 1              10.0                 19.69  2026-03-02
# 2               6.0                 37.46  2026-01-26
# 3              28.0                  6.37  2026-04-30
# 4              19.0                 39.22  2026-01-20
