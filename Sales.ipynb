# %%
import pandas as pd
import numpy as np
import seaborn as sms
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is AC60-AD3D
#
#  Directory of C:\Users\Lakshmi Priya\OneDrive\Documents\GitHub\Organic-food-tracebality
#
# 11-08-2026  23:01    <DIR>          .
# 27-07-2026  22:30    <DIR>          ..
# 11-08-2026  22:56    <DIR>          .ipynb_checkpoints
# 27-07-2026  23:29                 5 .python-version
# 28-07-2026  22:37    <DIR>          .venv
# 06-08-2026  22:39    <DIR>          __pycache__
# 06-08-2026  22:36             7,335 app.py
# 06-08-2026  20:48    <DIR>          assets
# 03-08-2026  21:45            13,176 cart_page.py
# 07-08-2026  23:33               156 categories.csv
# 07-08-2026  23:35            11,893 categories.ipynb
# 02-08-2026  21:43             2,964 categories.py
# 06-08-2026  22:36             2,526 category_page.py
# 06-08-2026  22:36    <DIR>          components
# 06-08-2026  22:36             1,059 config.py
# 11-08-2026  22:53         9,774,936 Customer.csv
# ...

# %%
s= pd.read_csv("Sales.csv")

# %%
s.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       0.0
# 1        2             16       25011         61         7       0.0
# 2        3             13       94024         23        24       0.0
# 3        4              8       73966        176        19       0.2
# 4        5             10       32653        310         9       0.0
#
#    TotalPrice                SalesDate     TransactionNumber
# 0         0.0  2018-02-05 07:38:25.430  FQL4S94E4ME1EZFTG42G
# 1         0.0  2018-02-02 16:03:31.150  12UGLX40DJ1A5DTFBHB8
# 2         0.0  2018-05-03 19:31:56.880  5DT8RCPL87KI5EORO7B0
# 3         0.0  2018-04-07 14:43:55.420  R3DR9MLD5NR76VO17ULE
# 4         0.0  2018-02-12 15:37:03.940  4BGS0Z5OMAZ8NDAFHHP3

# %% [raw]
# CREATE TABLE `Order_Details` (
# 	`order_id` INT NOT NULL AUTO_INCREMENT,
# 	`customer_id` INT NOT NULL,
# 	`product_id` INT NOT NULL,
# 	`product_count` INT NOT NULL,
# 	`product_price` DECIMAL(10,2) NOT NULL,
# 	`product_discount` DECIMAL(5,2) NOT NULL,
# 	`price_after_discount` DECIMAL(10,2) NOT NULL,
# 	`order_date` DATE NOT NULL,
# 	`order_time` TIME NOT NULL,
# 	PRIMARY KEY (`order_id`) USING BTREE,
# 	INDEX `fk_order_customer` (`customer_id`) USING BTREE,
# 	INDEX `fk_order_product` (`product_id`) USING BTREE,
# 	CONSTRAINT `fk_order_customer` FOREIGN KEY (`customer_id`) REFERENCES `Customer_Details` (`customer_id`) ON UPDATE NO ACTION ON DELETE NO ACTION,
# 	CONSTRAINT `fk_order_product` FOREIGN KEY (`product_id`) REFERENCES `Product` (`product_id`) ON UPDATE NO ACTION ON DELETE NO ACTION
# )
# COLLATE='utf8mb4_0900_ai_ci'
# ENGINE=InnoDB
# AUTO_INCREMENT=307
# ;

# %%
p=pd.read_csv("Products.csv")

# %%
p.head()
# Out:
#    product_id  category_id                product_name    price  \
# 0           1            3         Flour - Whole Wheat  74.2988
# 1           2            3  Cookie Chocolate Chip With  91.2329
# 2           3            9          Onions - Cippolini   9.1379
# 3           4            9  Sauce - Gravy, Au Jus, Mix  54.3055
# 4           5            2      Artichokes - Jerusalem  65.4771
#
#           manufacture_date              expiry_date  quantity  discount
# 0  2018-02-16 08:21:49.190  2018-03-18 08:21:49.190        73        10
# 1  2017-02-12 11:39:10.970  2017-03-14 11:39:10.970       100        29
# 2  2018-03-15 08:11:51.560  2018-04-14 08:11:51.560        78        17
# 3  2017-07-16 00:46:28.880  2017-08-15 00:46:28.880        95        24
# 4  2017-08-16 14:13:35.430  2017-09-15 14:13:35.430        98        17

# %%
s.rename(columns={'ProductID': 'product_id'}, inplace=True)

# %%
df=pd.merge(s,p,on="product_id")

# %%
df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  product_id  Quantity  Discount  \
# 0        1              6       27039         381         7       0.0
# 1        2             16       25011          61         7       0.0
# 2        3             13       94024          23        24       0.0
# 3        4              8       73966         176        19       0.2
# 4        5             10       32653         310         9       0.0
#
#    TotalPrice                SalesDate     TransactionNumber  category_id  \
# 0         0.0  2018-02-05 07:38:25.430  FQL4S94E4ME1EZFTG42G            1
# 1         0.0  2018-02-02 16:03:31.150  12UGLX40DJ1A5DTFBHB8            8
# 2         0.0  2018-05-03 19:31:56.880  5DT8RCPL87KI5EORO7B0           11
# 3         0.0  2018-04-07 14:43:55.420  R3DR9MLD5NR76VO17ULE            6
# 4         0.0  2018-02-12 15:37:03.940  4BGS0Z5OMAZ8NDAFHHP3            9
#
#                  product_name    price         manufacture_date  \
# ...

# %%
df.drop(['SalesPersonID','manufacture_date','expiry_date','quantity','Discount','TotalPrice','product_name'],inplace=True,axis=1)

# %%
df.head()
# Out:
#    SalesID  CustomerID  product_id  Quantity                SalesDate  \
# 0        1       27039         381         7  2018-02-05 07:38:25.430
# 1        2       25011          61         7  2018-02-02 16:03:31.150
# 2        3       94024          23        24  2018-05-03 19:31:56.880
# 3        4       73966         176        19  2018-04-07 14:43:55.420
# 4        5       32653         310         9  2018-02-12 15:37:03.940
#
#       TransactionNumber  category_id    price  discount
# 0  FQL4S94E4ME1EZFTG42G            1  44.2337        15
# 1  12UGLX40DJ1A5DTFBHB8            8  62.5460         8
# 2  5DT8RCPL87KI5EORO7B0           11  79.0184        27
# 3  R3DR9MLD5NR76VO17ULE            6  81.3167         5
# 4  4BGS0Z5OMAZ8NDAFHHP3            9  79.9780        15

# %%
CREATE TABLE `Order_Details` (
	`order_id` INT NOT NULL AUTO_INCREMENT,
	`customer_id` INT NOT NULL,
	`product_id` INT NOT NULL,
	`product_count` INT NOT NULL,
	`product_price` DECIMAL(10,2) NOT NULL,
	`product_discount` DECIMAL(5,2) NOT NULL,
	`price_after_discount` DECIMAL(10,2) NOT NULL,
	`order_date` DATE NOT NULL,
	`order_time` TIME NOT NULL,
	PRIMARY KEY (`order_id`) USING BTREE,
	INDEX `fk_order_customer` (`customer_id`) USING BTREE,
	INDEX `fk_order_product` (`product_id`) USING BTREE,
	CONSTRAINT `fk_order_customer` FOREIGN KEY (`customer_id`) REFERENCES `Customer_Details` (`customer_id`) ON UPDATE NO ACTION ON DELETE NO ACTION,
	CONSTRAINT `fk_order_product` FOREIGN KEY (`product_id`) REFERENCES `Product` (`product_id`) ON UPDATE NO ACTION ON DELETE NO ACTION
)
COLLATE='utf8mb4_0900_ai_ci'
ENGINE=InnoDB
AUTO_INCREMENT=307
;
