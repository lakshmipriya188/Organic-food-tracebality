# %%
import pandas as pd
import numpy as np
sales= pd.read_csv("sales_date.csv")
sales.dropna(inplace= True)
sales.isnull().sum()
# Out:
# order_id                0
# customer_id             0
# product_id              0
# product_count           0
# product_price           0
# product_discount        0
# price_after_discount    0
# order_date              0
# dtype: int64

# %%
sales.head()
# Out:
#    order_id  customer_id  product_id  product_count  product_price  \
# 0         6        28663         413              8        95.4065
# 1         7        46674         370             12        21.8806
# 2        15        19310         134              5        39.8545
# 3        16        91867         364             24         8.8429
# 4        17        14612         185              4        48.4195
#
#    product_discount  price_after_discount  order_date
# 0                 5                 90.64  2026-02-07
# 1                10                 19.69  2026-03-02
# 2                 6                 37.46  2026-01-26
# 3                28                  6.37  2026-04-30
# 4                19                 39.22  2026-01-20

# %%
sales.shape
# Out:
# (1494806, 8)

# %% [markdown]
# # Feature Creation Cus*order_date ---------- Product ------

# %%
df = sales#.sample(100)

df['order_date'] = pd.to_datetime(df['order_date'])

df["day_of_week"] = df["order_date"].dt.dayofweek
df["day_of_month"] = df["order_date"].dt.day
df["month"] = df["order_date"].dt.month
df["quarter"] = df["order_date"].dt.quarter
df["week_of_year"] = df["order_date"].dt.isocalendar().week
df["is_weekend"] = df["day_of_week"].isin([5, 6]).astype(int)

# %%
df.dtypes
# Out:
# order_id                         int64
# customer_id                      int64
# product_id                       int64
# product_count                    int64
# product_price                  float64
# product_discount                 int64
# price_after_discount           float64
# order_date              datetime64[ns]
# day_of_week                      int32
# day_of_month                     int32
# month                            int32
# quarter                          int32
# week_of_year                    UInt32
# is_weekend                       int64
# dtype: object

# %%
df['spend'] =df['price_after_discount']*df['product_count']
df.head()
# Out:
#          order_id  customer_id  product_id  product_count  product_price  \
# 1412202   6321956        70591         370             18        21.8806
# 227010    1015282        16911         327              5         7.1436
# 1168185   5232134        36883         120             10         2.7314
# 624647    2794335        91650         209             24        32.9885
# 488835    2187261        12009         147              4        49.6197
#
#          product_discount  price_after_discount order_date  day_of_week  \
# 1412202                10                 19.69 2026-01-07            2
# 227010                 20                  5.71 2026-03-02            0
# 1168185                16                  2.29 2026-01-21            2
# 624647                 13                 28.70 2026-03-11            2
# 488835                 15                 42.18 2026-01-14            2
#
#          day_of_month  month  quarter  week_of_year  is_weekend   spend
# 1412202             7      1        1             2           0  354.42
# 227010              2      3        1            10           0   28.55
# 1168185            21      1        1             4           0   22.90
# 624647             11      3        1            11           0  688.80
# 488835             14      1        1             3           0  168.72

# %% [markdown]
# # Feautures 1

# %%
cpd = (
    df.groupby(
        ["customer_id", "product_id", "order_date"],
        as_index=False
    )
    .agg(
        purchase_count=("order_id", "count"),

        # Quantity
        avg_quantity=("product_count", "mean"),
        max_quantity=("product_count", "max"),
        p25_quantity=("product_count", lambda x: x.quantile(0.25)),
        p50_quantity=("product_count", lambda x: x.quantile(0.50)),
        p75_quantity=("product_count", lambda x: x.quantile(0.75)),
        p90_quantity=("product_count", lambda x: x.quantile(0.90)),
        p95_quantity=("product_count", lambda x: x.quantile(0.95)),

        # Spend
        total_spend=("spend", "sum"),
        avg_spend=("spend", "mean"),
        min_spend=("spend", "min"),
        max_spend=("spend", "max"),
        p25_spend=("spend", lambda x: x.quantile(0.25)),
        p50_spend=("spend", lambda x: x.quantile(0.50)),
        p75_spend=("spend", lambda x: x.quantile(0.75)),
        p90_spend=("spend", lambda x: x.quantile(0.90)),
        p95_spend=("spend", lambda x: x.quantile(0.95)),

        # Price after discount
        total_pad=("price_after_discount", "sum"),
        avg_pad=("price_after_discount", "mean"),
        min_pad=("price_after_discount", "min"),
        max_pad=("price_after_discount", "max"),
        p25_pad=("price_after_discount", lambda x: x.quantile(0.25)),
        p50_pad=("price_after_discount", lambda x: x.quantile(0.50)),
        p75_pad=("price_after_discount", lambda x: x.quantile(0.75)),
        p90_pad=("price_after_discount", lambda x: x.quantile(0.90)),
        p95_pad=("price_after_discount", lambda x: x.quantile(0.95)),

        # Product count
        total_pc=("product_count", "sum"),
        avg_pc=("product_count", "mean"),
        min_pc=("product_count", "min"),
        max_pc=("product_count", "max"),
        p25_pc=("product_count", lambda x: x.quantile(0.25)),
        p50_pc=("product_count", lambda x: x.quantile(0.50)),
        p75_pc=("product_count", lambda x: x.quantile(0.75)),
        p90_pc=("product_count", lambda x: x.quantile(0.90)),
        p95_pc=("product_count", lambda x: x.quantile(0.95)),

        # Product discount
        total_pd=("product_discount", "sum"),
        avg_pd=("product_discount", "mean"),
        min_pd=("product_discount", "min"),
        max_pd=("product_discount", "max"),
        p25_pd=("product_discount", lambda x: x.quantile(0.25)),
        p50_pd=("product_discount", lambda x: x.quantile(0.50)),
        p75_pd=("product_discount", lambda x: x.quantile(0.75)),
        p90_pd=("product_discount", lambda x: x.quantile(0.90)),
        p95_pd=("product_discount", lambda x: x.quantile(0.95)),
        
        # Product price
        total_pp=("product_price", "sum"),
        avg_pp=("product_price", "mean"),
        min_pp=("product_price", "min"),
        max_pp=("product_price", "max"),
        p25_pp=("product_price", lambda x: x.quantile(0.25)),
        p50_pp=("product_price", lambda x: x.quantile(0.50)),
        p75_pp=("product_price", lambda x: x.quantile(0.75)),
        p90_pp=("product_price", lambda x: x.quantile(0.90)),
        p95_pp=("product_price", lambda x: x.quantile(0.95)),
    )
)

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 53
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp']

# %%
cpd = cpd.sort_values( ["customer_id", "order_date"]).copy()
for i in cpd.columns:
    cpd[f"last_{i}"] = (cpd.groupby("customer_id")[i] .shift(1) )

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 109
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp', 'last_customer_id', 'last_product_id']
# ['last_order_date', 'last_purchase_count', 'last_avg_quantity', 'last_max_quantity', 'last_p25_quantity']
# ['last_p50_quantity', 'last_p75_quantity', 'last_p90_quantity', 'last_p95_quantity', 'last_total_spend']
# ['last_avg_spend', 'last_min_spend', 'last_max_spend', 'last_p25_spend', 'last_p50_spend']
# ['last_p75_spend', 'last_p90_spend', 'last_p95_spend', 'last_total_pad', 'last_avg_pad']
# ['last_min_pad', 'last_max_pad', 'last_p25_pad', 'last_p50_pad', 'last_p75_pad']
# ['last_p90_pad', 'last_p95_pad', 'last_total_pc', 'last_avg_pc', 'last_min_pc']
# ['last_max_pc', 'last_p25_pc', 'last_p50_pc', 'last_p75_pc', 'last_p90_pc']
# ['last_p95_pc', 'last_total_pd', 'last_avg_pd', 'last_min_pd', 'last_max_pd']
# ['last_p25_pd', 'last_p50_pd', 'last_p75_pd', 'last_p90_pd', 'last_p95_pd']
# ['last_total_pp', 'last_avg_pp', 'last_min_pp', 'last_max_pp', 'last_p25_pp']
# ['last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp']

# %%
cpd["Same_order"] = (cpd["product_id"] == cpd["last_product_id"]).astype(int)
cpd["Same_date_as_last"] = ( cpd["order_date"] == cpd["last_order_date"] ).astype(int)
cpd["Last_transaction_days"] = (cpd["order_date"] - cpd["last_order_date"] ).dt.days

cpd.drop(['last_customer_id','last_product_id'],axis=1 , inplace = True)

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 110
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp', 'last_order_date', 'last_purchase_count']
# ['last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity']
# ['last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend']
# ['last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend', 'last_p90_spend']
# ['last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad']
# ['last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad', 'last_p95_pad']
# ['last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc']
# ['last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc', 'last_total_pd']
# ['last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd']
# ['last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp', 'last_avg_pp']
# ['last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp']
# ['last_p90_pp', 'last_p95_pp', 'Same_order', 'Same_date_as_last', 'Last_transaction_days']

# %%
cpd = cpd.sort_values(
    ["customer_id", "product_id", "order_date"]
).copy()

original_columns = cpd.columns[:56].tolist()

last_features = (
    cpd.groupby(["customer_id", "product_id"])[original_columns]
       .shift(1)
)

last_features.columns = [
    f"last_pc_{col}" for col in original_columns
]

cpd = pd.concat(
    [cpd, last_features],
    axis=1
)

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 166
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp', 'last_order_date', 'last_purchase_count']
# ['last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity']
# ['last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend']
# ['last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend', 'last_p90_spend']
# ['last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad']
# ['last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad', 'last_p95_pad']
# ['last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc']
# ['last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc', 'last_total_pd']
# ['last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd']
# ['last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp', 'last_avg_pp']
# ['last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp']
# ['last_p90_pp', 'last_p95_pp', 'Same_order', 'Same_date_as_last', 'Last_transaction_days']
# ['last_pc_customer_id', 'last_pc_product_id', 'last_pc_order_date', 'last_pc_purchase_count', 'last_pc_avg_quantity']
# ['last_pc_max_quantity', 'last_pc_p25_quantity', 'last_pc_p50_quantity', 'last_pc_p75_quantity', 'last_pc_p90_quantity']
# ['last_pc_p95_quantity', 'last_pc_total_spend', 'last_pc_avg_spend', 'last_pc_min_spend', 'last_pc_max_spend']
# ['last_pc_p25_spend', 'last_pc_p50_spend', 'last_pc_p75_spend', 'last_pc_p90_spend', 'last_pc_p95_spend']
# ['last_pc_total_pad', 'last_pc_avg_pad', 'last_pc_min_pad', 'last_pc_max_pad', 'last_pc_p25_pad']
# ['last_pc_p50_pad', 'last_pc_p75_pad', 'last_pc_p90_pad', 'last_pc_p95_pad', 'last_pc_total_pc']
# ['last_pc_avg_pc', 'last_pc_min_pc', 'last_pc_max_pc', 'last_pc_p25_pc', 'last_pc_p50_pc']
# ['last_pc_p75_pc', 'last_pc_p90_pc', 'last_pc_p95_pc', 'last_pc_total_pd', 'last_pc_avg_pd']
# ['last_pc_min_pd', 'last_pc_max_pd', 'last_pc_p25_pd', 'last_pc_p50_pd', 'last_pc_p75_pd']
# ['last_pc_p90_pd', 'last_pc_p95_pd', 'last_pc_total_pp', 'last_pc_avg_pp', 'last_pc_min_pp']
# ['last_pc_max_pp', 'last_pc_p25_pp', 'last_pc_p50_pp', 'last_pc_p75_pp', 'last_pc_p90_pp']
# ['last_pc_p95_pp']

# %%
cpd["Repeated"] = (cpd["purchase_count"] > 1).astype(int)

# %%
columns = cpd.columns[3:]
print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 167
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp', 'last_order_date', 'last_purchase_count']
# ['last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity']
# ['last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend']
# ['last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend', 'last_p90_spend']
# ['last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad']
# ['last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad', 'last_p95_pad']
# ['last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc']
# ['last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc', 'last_total_pd']
# ['last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd']
# ['last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp', 'last_avg_pp']
# ['last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp']
# ['last_p90_pp', 'last_p95_pp', 'Same_order', 'Same_date_as_last', 'Last_transaction_days']
# ['last_pc_customer_id', 'last_pc_product_id', 'last_pc_order_date', 'last_pc_purchase_count', 'last_pc_avg_quantity']
# ['last_pc_max_quantity', 'last_pc_p25_quantity', 'last_pc_p50_quantity', 'last_pc_p75_quantity', 'last_pc_p90_quantity']
# ['last_pc_p95_quantity', 'last_pc_total_spend', 'last_pc_avg_spend', 'last_pc_min_spend', 'last_pc_max_spend']
# ['last_pc_p25_spend', 'last_pc_p50_spend', 'last_pc_p75_spend', 'last_pc_p90_spend', 'last_pc_p95_spend']
# ['last_pc_total_pad', 'last_pc_avg_pad', 'last_pc_min_pad', 'last_pc_max_pad', 'last_pc_p25_pad']
# ['last_pc_p50_pad', 'last_pc_p75_pad', 'last_pc_p90_pad', 'last_pc_p95_pad', 'last_pc_total_pc']
# ['last_pc_avg_pc', 'last_pc_min_pc', 'last_pc_max_pc', 'last_pc_p25_pc', 'last_pc_p50_pc']
# ['last_pc_p75_pc', 'last_pc_p90_pc', 'last_pc_p95_pc', 'last_pc_total_pd', 'last_pc_avg_pd']
# ['last_pc_min_pd', 'last_pc_max_pd', 'last_pc_p25_pd', 'last_pc_p50_pd', 'last_pc_p75_pd']
# ['last_pc_p90_pd', 'last_pc_p95_pd', 'last_pc_total_pp', 'last_pc_avg_pp', 'last_pc_min_pp']
# ['last_pc_max_pp', 'last_pc_p25_pp', 'last_pc_p50_pp', 'last_pc_p75_pp', 'last_pc_p90_pp']
# ['last_pc_p95_pp', 'Repeated']

# %%
new_cols = [    'purchase_count', 'avg_quantity', 'max_quantity',
                #'p25_quantity','p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity',
                'total_spend', 'avg_spend', 'min_spend', 'max_spend',
                #'p25_spend','p50_spend', 'p75_spend', 'p90_spend', 'p95_spend',
                'total_pad','avg_pad', 'min_pad', 'max_pad', 
                #'p25_pad', 'p50_pad', 'p75_pad','p90_pad', 'p95_pad',
                'total_pc', 'avg_pc', 'min_pc', 'max_pc',
                #'p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 
                'total_pd', 'avg_pd','min_pd', 'max_pd', 
                #'p25_pd', 'p50_pd', 'p75_pd', 'p90_pd', 'p95_pd',
                'total_pp', 'avg_pp', 'min_pp', 'max_pp',
                #'p25_pp', 'p50_pp', 'p75_pp','p90_pp', 'p95_pp' 
           ]

# %%
for i in new_cols : 
    windows = [2, 3, 7, 30, 60, 90]
    group_cols = ["customer_id", "product_id"]
    # Variables for which you want historical rolling features
    rolling_cols = [ i ]
    
    cpd = cpd.sort_values( group_cols + ["order_date"] ).reset_index(drop=True)
    cpd["order_date"] = pd.to_datetime(cpd["order_date"])
    for col in rolling_cols:
        print(f"\nProcessing: {col}")
        temp = cpd[ group_cols + ["order_date", col] ].copy()
        temp[col] = ( temp.groupby(group_cols)[col].shift(1) )
        temp = temp.set_index("order_date")
        rolling = (temp.groupby(group_cols)[col].rolling("2D", closed="both"))
    
        for days in windows:
            rolling = (temp.groupby(group_cols)[col].rolling( f"{days}D", closed="both", min_periods=1))
            cpd[f"{col}_{days}d_mean"] = ( rolling.mean() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_min"]  = ( rolling.min() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_max"]  = ( rolling.max() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_std"]  = ( rolling.std() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_var"]  = ( rolling.var() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p25"]  = ( rolling.quantile(0.25) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p50"]  = ( rolling.quantile(0.50) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p75"]  = ( rolling.quantile(0.75) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p90"]  = ( rolling.quantile(0.90) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p95"]  = ( rolling.quantile(0.95) .reset_index(level=group_cols, drop=True) .to_numpy())
    
    cpd = cpd.sort_values( group_cols + ["order_date"] ).reset_index(drop=True)
    
    rolling_features = [
        c for c in cpd.columns
        if any( f"_{d}d_" in c for d in windows ) ]
    
    print("\nNumber of rolling features:", len(rolling_features))
    
#print("\nRolling features:")
#print(rolling_features)
# Out:
# Processing: purchase_count
#
# Number of rolling features: 1380
#
# Processing: avg_quantity
#
# Number of rolling features: 1380
#
# Processing: max_quantity
#
# Number of rolling features: 1380
#
# Processing: total_spend
#
# Number of rolling features: 1380
#
# Processing: avg_spend
#
# Number of rolling features: 1380
#
# Processing: min_spend
#
# Number of rolling features: 1380
#
# Processing: max_spend
#
# Number of rolling features: 1380
#
# Processing: total_pad
#
# Number of rolling features: 1380
#
# Processing: avg_pad
#
# Number of rolling features: 1380
#
# Processing: min_pad
#
# Number of rolling features: 1380
#
# Processing: max_pad
#
# Number of rolling features: 1380
#
# Processing: total_pc
#
# Number of rolling features: 1380
#
# Processing: avg_pc
#
# Number of rolling features: 1380
#
# Processing: min_pc
#
# Number of rolling features: 1380
#
# Processing: max_pc
#
# Number of rolling features: 1380
#
# Processing: total_pd
#
# Number of rolling features: 1380
#
# Processing: avg_pd
#
# Number of rolling features: 1380
#
# Processing: min_pd
#
# Number of rolling features: 1380
#
# Processing: max_pd
#
# Number of rolling features: 1380
#
# Processing: total_pp
#
# Number of rolling features: 1380
#
# Processing: avg_pp
#
# Number of rolling features: 1380
#
# Processing: min_pp
#
# Number of rolling features: 1380
#
# Processing: max_pp
#
# Number of rolling features: 1380

# %%
columns = cpd.columns[3:]
print("=" * 100)
print(f"Total columns: {len(columns)}")
print("=" * 100)
for i in range(0, len(columns), 5):
    print(columns[i:i+5].tolist())
# Out:
# ====================================================================================================
# Total columns: 1547
# ====================================================================================================
# ['purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity']
# ['p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend']
# ['min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend']
# ['p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad']
# ['max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad']
# ['p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc']
# ['p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc']
# ['total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd']
# ['p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp']
# ['avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp']
# ['p75_pp', 'p90_pp', 'p95_pp', 'last_order_date', 'last_purchase_count']
# ['last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity']
# ['last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend']
# ['last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend', 'last_p90_spend']
# ['last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad']
# ['last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad', 'last_p95_pad']
# ['last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc']
# ['last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc', 'last_total_pd']
# ['last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd']
# ['last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp', 'last_avg_pp']
# ['last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp']
# ['last_p90_pp', 'last_p95_pp', 'Same_order', 'Same_date_as_last', 'Last_transaction_days']
# ['last_pc_customer_id', 'last_pc_product_id', 'last_pc_order_date', 'last_pc_purchase_count', 'last_pc_avg_quantity']
# ['last_pc_max_quantity', 'last_pc_p25_quantity', 'last_pc_p50_quantity', 'last_pc_p75_quantity', 'last_pc_p90_quantity']
# ['last_pc_p95_quantity', 'last_pc_total_spend', 'last_pc_avg_spend', 'last_pc_min_spend', 'last_pc_max_spend']
# ['last_pc_p25_spend', 'last_pc_p50_spend', 'last_pc_p75_spend', 'last_pc_p90_spend', 'last_pc_p95_spend']
# ['last_pc_total_pad', 'last_pc_avg_pad', 'last_pc_min_pad', 'last_pc_max_pad', 'last_pc_p25_pad']
# ['last_pc_p50_pad', 'last_pc_p75_pad', 'last_pc_p90_pad', 'last_pc_p95_pad', 'last_pc_total_pc']
# ['last_pc_avg_pc', 'last_pc_min_pc', 'last_pc_max_pc', 'last_pc_p25_pc', 'last_pc_p50_pc']
# ['last_pc_p75_pc', 'last_pc_p90_pc', 'last_pc_p95_pc', 'last_pc_total_pd', 'last_pc_avg_pd']
# ['last_pc_min_pd', 'last_pc_max_pd', 'last_pc_p25_pd', 'last_pc_p50_pd', 'last_pc_p75_pd']
# ['last_pc_p90_pd', 'last_pc_p95_pd', 'last_pc_total_pp', 'last_pc_avg_pp', 'last_pc_min_pp']
# ['last_pc_max_pp', 'last_pc_p25_pp', 'last_pc_p50_pp', 'last_pc_p75_pp', 'last_pc_p90_pp']
# ['last_pc_p95_pp', 'Repeated', 'purchase_count_2d_mean', 'purchase_count_2d_min', 'purchase_count_2d_max']
# ['purchase_count_2d_std', 'purchase_count_2d_var', 'purchase_count_2d_p25', 'purchase_count_2d_p50', 'purchase_count_2d_p75']
# ['purchase_count_2d_p90', 'purchase_count_2d_p95', 'purchase_count_3d_mean', 'purchase_count_3d_min', 'purchase_count_3d_max']
# ['purchase_count_3d_std', 'purchase_count_3d_var', 'purchase_count_3d_p25', 'purchase_count_3d_p50', 'purchase_count_3d_p75']
# ['purchase_count_3d_p90', 'purchase_count_3d_p95', 'purchase_count_7d_mean', 'purchase_count_7d_min', 'purchase_count_7d_max']
# ['purchase_count_7d_std', 'purchase_count_7d_var', 'purchase_count_7d_p25', 'purchase_count_7d_p50', 'purchase_count_7d_p75']
# ['purchase_count_7d_p90', 'purchase_count_7d_p95', 'purchase_count_30d_mean', 'purchase_count_30d_min', 'purchase_count_30d_max']
# ['purchase_count_30d_std', 'purchase_count_30d_var', 'purchase_count_30d_p25', 'purchase_count_30d_p50', 'purchase_count_30d_p75']
# ['purchase_count_30d_p90', 'purchase_count_30d_p95', 'purchase_count_60d_mean', 'purchase_count_60d_min', 'purchase_count_60d_max']
# ['purchase_count_60d_std', 'purchase_count_60d_var', 'purchase_count_60d_p25', 'purchase_count_60d_p50', 'purchase_count_60d_p75']
# ['purchase_count_60d_p90', 'purchase_count_60d_p95', 'purchase_count_90d_mean', 'purchase_count_90d_min', 'purchase_count_90d_max']
# ['purchase_count_90d_std', 'purchase_count_90d_var', 'purchase_count_90d_p25', 'purchase_count_90d_p50', 'purchase_count_90d_p75']
# ['purchase_count_90d_p90', 'purchase_count_90d_p95', 'avg_quantity_2d_mean', 'avg_quantity_2d_min', 'avg_quantity_2d_max']
# ['avg_quantity_2d_std', 'avg_quantity_2d_var', 'avg_quantity_2d_p25', 'avg_quantity_2d_p50', 'avg_quantity_2d_p75']
# ['avg_quantity_2d_p90', 'avg_quantity_2d_p95', 'avg_quantity_3d_mean', 'avg_quantity_3d_min', 'avg_quantity_3d_max']
# ['avg_quantity_3d_std', 'avg_quantity_3d_var', 'avg_quantity_3d_p25', 'avg_quantity_3d_p50', 'avg_quantity_3d_p75']
# ['avg_quantity_3d_p90', 'avg_quantity_3d_p95', 'avg_quantity_7d_mean', 'avg_quantity_7d_min', 'avg_quantity_7d_max']
# ['avg_quantity_7d_std', 'avg_quantity_7d_var', 'avg_quantity_7d_p25', 'avg_quantity_7d_p50', 'avg_quantity_7d_p75']
# ['avg_quantity_7d_p90', 'avg_quantity_7d_p95', 'avg_quantity_30d_mean', 'avg_quantity_30d_min', 'avg_quantity_30d_max']
# ['avg_quantity_30d_std', 'avg_quantity_30d_var', 'avg_quantity_30d_p25', 'avg_quantity_30d_p50', 'avg_quantity_30d_p75']
# ['avg_quantity_30d_p90', 'avg_quantity_30d_p95', 'avg_quantity_60d_mean', 'avg_quantity_60d_min', 'avg_quantity_60d_max']
# ['avg_quantity_60d_std', 'avg_quantity_60d_var', 'avg_quantity_60d_p25', 'avg_quantity_60d_p50', 'avg_quantity_60d_p75']
# ['avg_quantity_60d_p90', 'avg_quantity_60d_p95', 'avg_quantity_90d_mean', 'avg_quantity_90d_min', 'avg_quantity_90d_max']
# ['avg_quantity_90d_std', 'avg_quantity_90d_var', 'avg_quantity_90d_p25', 'avg_quantity_90d_p50', 'avg_quantity_90d_p75']
# ['avg_quantity_90d_p90', 'avg_quantity_90d_p95', 'max_quantity_2d_mean', 'max_quantity_2d_min', 'max_quantity_2d_max']
# ['max_quantity_2d_std', 'max_quantity_2d_var', 'max_quantity_2d_p25', 'max_quantity_2d_p50', 'max_quantity_2d_p75']
# ['max_quantity_2d_p90', 'max_quantity_2d_p95', 'max_quantity_3d_mean', 'max_quantity_3d_min', 'max_quantity_3d_max']
# ['max_quantity_3d_std', 'max_quantity_3d_var', 'max_quantity_3d_p25', 'max_quantity_3d_p50', 'max_quantity_3d_p75']
# ['max_quantity_3d_p90', 'max_quantity_3d_p95', 'max_quantity_7d_mean', 'max_quantity_7d_min', 'max_quantity_7d_max']
# ['max_quantity_7d_std', 'max_quantity_7d_var', 'max_quantity_7d_p25', 'max_quantity_7d_p50', 'max_quantity_7d_p75']
# ['max_quantity_7d_p90', 'max_quantity_7d_p95', 'max_quantity_30d_mean', 'max_quantity_30d_min', 'max_quantity_30d_max']
# ['max_quantity_30d_std', 'max_quantity_30d_var', 'max_quantity_30d_p25', 'max_quantity_30d_p50', 'max_quantity_30d_p75']
# ['max_quantity_30d_p90', 'max_quantity_30d_p95', 'max_quantity_60d_mean', 'max_quantity_60d_min', 'max_quantity_60d_max']
# ['max_quantity_60d_std', 'max_quantity_60d_var', 'max_quantity_60d_p25', 'max_quantity_60d_p50', 'max_quantity_60d_p75']
# ['max_quantity_60d_p90', 'max_quantity_60d_p95', 'max_quantity_90d_mean', 'max_quantity_90d_min', 'max_quantity_90d_max']
# ['max_quantity_90d_std', 'max_quantity_90d_var', 'max_quantity_90d_p25', 'max_quantity_90d_p50', 'max_quantity_90d_p75']
# ['max_quantity_90d_p90', 'max_quantity_90d_p95', 'total_spend_2d_mean', 'total_spend_2d_min', 'total_spend_2d_max']
# ['total_spend_2d_std', 'total_spend_2d_var', 'total_spend_2d_p25', 'total_spend_2d_p50', 'total_spend_2d_p75']
# ['total_spend_2d_p90', 'total_spend_2d_p95', 'total_spend_3d_mean', 'total_spend_3d_min', 'total_spend_3d_max']
# ['total_spend_3d_std', 'total_spend_3d_var', 'total_spend_3d_p25', 'total_spend_3d_p50', 'total_spend_3d_p75']
# ['total_spend_3d_p90', 'total_spend_3d_p95', 'total_spend_7d_mean', 'total_spend_7d_min', 'total_spend_7d_max']
# ['total_spend_7d_std', 'total_spend_7d_var', 'total_spend_7d_p25', 'total_spend_7d_p50', 'total_spend_7d_p75']
# ['total_spend_7d_p90', 'total_spend_7d_p95', 'total_spend_30d_mean', 'total_spend_30d_min', 'total_spend_30d_max']
# ['total_spend_30d_std', 'total_spend_30d_var', 'total_spend_30d_p25', 'total_spend_30d_p50', 'total_spend_30d_p75']
# ['total_spend_30d_p90', 'total_spend_30d_p95', 'total_spend_60d_mean', 'total_spend_60d_min', 'total_spend_60d_max']
# ['total_spend_60d_std', 'total_spend_60d_var', 'total_spend_60d_p25', 'total_spend_60d_p50', 'total_spend_60d_p75']
# ['total_spend_60d_p90', 'total_spend_60d_p95', 'total_spend_90d_mean', 'total_spend_90d_min', 'total_spend_90d_max']
# ['total_spend_90d_std', 'total_spend_90d_var', 'total_spend_90d_p25', 'total_spend_90d_p50', 'total_spend_90d_p75']
# ['total_spend_90d_p90', 'total_spend_90d_p95', 'avg_spend_2d_mean', 'avg_spend_2d_min', 'avg_spend_2d_max']
# ['avg_spend_2d_std', 'avg_spend_2d_var', 'avg_spend_2d_p25', 'avg_spend_2d_p50', 'avg_spend_2d_p75']
# ['avg_spend_2d_p90', 'avg_spend_2d_p95', 'avg_spend_3d_mean', 'avg_spend_3d_min', 'avg_spend_3d_max']
# ['avg_spend_3d_std', 'avg_spend_3d_var', 'avg_spend_3d_p25', 'avg_spend_3d_p50', 'avg_spend_3d_p75']
# ['avg_spend_3d_p90', 'avg_spend_3d_p95', 'avg_spend_7d_mean', 'avg_spend_7d_min', 'avg_spend_7d_max']
# ['avg_spend_7d_std', 'avg_spend_7d_var', 'avg_spend_7d_p25', 'avg_spend_7d_p50', 'avg_spend_7d_p75']
# ['avg_spend_7d_p90', 'avg_spend_7d_p95', 'avg_spend_30d_mean', 'avg_spend_30d_min', 'avg_spend_30d_max']
# ['avg_spend_30d_std', 'avg_spend_30d_var', 'avg_spend_30d_p25', 'avg_spend_30d_p50', 'avg_spend_30d_p75']
# ['avg_spend_30d_p90', 'avg_spend_30d_p95', 'avg_spend_60d_mean', 'avg_spend_60d_min', 'avg_spend_60d_max']
# ['avg_spend_60d_std', 'avg_spend_60d_var', 'avg_spend_60d_p25', 'avg_spend_60d_p50', 'avg_spend_60d_p75']
# ['avg_spend_60d_p90', 'avg_spend_60d_p95', 'avg_spend_90d_mean', 'avg_spend_90d_min', 'avg_spend_90d_max']
# ['avg_spend_90d_std', 'avg_spend_90d_var', 'avg_spend_90d_p25', 'avg_spend_90d_p50', 'avg_spend_90d_p75']
# ['avg_spend_90d_p90', 'avg_spend_90d_p95', 'min_spend_2d_mean', 'min_spend_2d_min', 'min_spend_2d_max']
# ['min_spend_2d_std', 'min_spend_2d_var', 'min_spend_2d_p25', 'min_spend_2d_p50', 'min_spend_2d_p75']
# ['min_spend_2d_p90', 'min_spend_2d_p95', 'min_spend_3d_mean', 'min_spend_3d_min', 'min_spend_3d_max']
# ['min_spend_3d_std', 'min_spend_3d_var', 'min_spend_3d_p25', 'min_spend_3d_p50', 'min_spend_3d_p75']
# ['min_spend_3d_p90', 'min_spend_3d_p95', 'min_spend_7d_mean', 'min_spend_7d_min', 'min_spend_7d_max']
# ['min_spend_7d_std', 'min_spend_7d_var', 'min_spend_7d_p25', 'min_spend_7d_p50', 'min_spend_7d_p75']
# ['min_spend_7d_p90', 'min_spend_7d_p95', 'min_spend_30d_mean', 'min_spend_30d_min', 'min_spend_30d_max']
# ['min_spend_30d_std', 'min_spend_30d_var', 'min_spend_30d_p25', 'min_spend_30d_p50', 'min_spend_30d_p75']
# ['min_spend_30d_p90', 'min_spend_30d_p95', 'min_spend_60d_mean', 'min_spend_60d_min', 'min_spend_60d_max']
# ['min_spend_60d_std', 'min_spend_60d_var', 'min_spend_60d_p25', 'min_spend_60d_p50', 'min_spend_60d_p75']
# ['min_spend_60d_p90', 'min_spend_60d_p95', 'min_spend_90d_mean', 'min_spend_90d_min', 'min_spend_90d_max']
# ['min_spend_90d_std', 'min_spend_90d_var', 'min_spend_90d_p25', 'min_spend_90d_p50', 'min_spend_90d_p75']
# ['min_spend_90d_p90', 'min_spend_90d_p95', 'max_spend_2d_mean', 'max_spend_2d_min', 'max_spend_2d_max']
# ['max_spend_2d_std', 'max_spend_2d_var', 'max_spend_2d_p25', 'max_spend_2d_p50', 'max_spend_2d_p75']
# ['max_spend_2d_p90', 'max_spend_2d_p95', 'max_spend_3d_mean', 'max_spend_3d_min', 'max_spend_3d_max']
# ['max_spend_3d_std', 'max_spend_3d_var', 'max_spend_3d_p25', 'max_spend_3d_p50', 'max_spend_3d_p75']
# ['max_spend_3d_p90', 'max_spend_3d_p95', 'max_spend_7d_mean', 'max_spend_7d_min', 'max_spend_7d_max']
# ['max_spend_7d_std', 'max_spend_7d_var', 'max_spend_7d_p25', 'max_spend_7d_p50', 'max_spend_7d_p75']
# ['max_spend_7d_p90', 'max_spend_7d_p95', 'max_spend_30d_mean', 'max_spend_30d_min', 'max_spend_30d_max']
# ['max_spend_30d_std', 'max_spend_30d_var', 'max_spend_30d_p25', 'max_spend_30d_p50', 'max_spend_30d_p75']
# ['max_spend_30d_p90', 'max_spend_30d_p95', 'max_spend_60d_mean', 'max_spend_60d_min', 'max_spend_60d_max']
# ['max_spend_60d_std', 'max_spend_60d_var', 'max_spend_60d_p25', 'max_spend_60d_p50', 'max_spend_60d_p75']
# ['max_spend_60d_p90', 'max_spend_60d_p95', 'max_spend_90d_mean', 'max_spend_90d_min', 'max_spend_90d_max']
# ['max_spend_90d_std', 'max_spend_90d_var', 'max_spend_90d_p25', 'max_spend_90d_p50', 'max_spend_90d_p75']
# ['max_spend_90d_p90', 'max_spend_90d_p95', 'total_pad_2d_mean', 'total_pad_2d_min', 'total_pad_2d_max']
# ['total_pad_2d_std', 'total_pad_2d_var', 'total_pad_2d_p25', 'total_pad_2d_p50', 'total_pad_2d_p75']
# ['total_pad_2d_p90', 'total_pad_2d_p95', 'total_pad_3d_mean', 'total_pad_3d_min', 'total_pad_3d_max']
# ['total_pad_3d_std', 'total_pad_3d_var', 'total_pad_3d_p25', 'total_pad_3d_p50', 'total_pad_3d_p75']
# ['total_pad_3d_p90', 'total_pad_3d_p95', 'total_pad_7d_mean', 'total_pad_7d_min', 'total_pad_7d_max']
# ['total_pad_7d_std', 'total_pad_7d_var', 'total_pad_7d_p25', 'total_pad_7d_p50', 'total_pad_7d_p75']
# ['total_pad_7d_p90', 'total_pad_7d_p95', 'total_pad_30d_mean', 'total_pad_30d_min', 'total_pad_30d_max']
# ['total_pad_30d_std', 'total_pad_30d_var', 'total_pad_30d_p25', 'total_pad_30d_p50', 'total_pad_30d_p75']
# ['total_pad_30d_p90', 'total_pad_30d_p95', 'total_pad_60d_mean', 'total_pad_60d_min', 'total_pad_60d_max']
# ['total_pad_60d_std', 'total_pad_60d_var', 'total_pad_60d_p25', 'total_pad_60d_p50', 'total_pad_60d_p75']
# ['total_pad_60d_p90', 'total_pad_60d_p95', 'total_pad_90d_mean', 'total_pad_90d_min', 'total_pad_90d_max']
# ['total_pad_90d_std', 'total_pad_90d_var', 'total_pad_90d_p25', 'total_pad_90d_p50', 'total_pad_90d_p75']
# ['total_pad_90d_p90', 'total_pad_90d_p95', 'avg_pad_2d_mean', 'avg_pad_2d_min', 'avg_pad_2d_max']
# ['avg_pad_2d_std', 'avg_pad_2d_var', 'avg_pad_2d_p25', 'avg_pad_2d_p50', 'avg_pad_2d_p75']
# ['avg_pad_2d_p90', 'avg_pad_2d_p95', 'avg_pad_3d_mean', 'avg_pad_3d_min', 'avg_pad_3d_max']
# ['avg_pad_3d_std', 'avg_pad_3d_var', 'avg_pad_3d_p25', 'avg_pad_3d_p50', 'avg_pad_3d_p75']
# ['avg_pad_3d_p90', 'avg_pad_3d_p95', 'avg_pad_7d_mean', 'avg_pad_7d_min', 'avg_pad_7d_max']
# ['avg_pad_7d_std', 'avg_pad_7d_var', 'avg_pad_7d_p25', 'avg_pad_7d_p50', 'avg_pad_7d_p75']
# ['avg_pad_7d_p90', 'avg_pad_7d_p95', 'avg_pad_30d_mean', 'avg_pad_30d_min', 'avg_pad_30d_max']
# ['avg_pad_30d_std', 'avg_pad_30d_var', 'avg_pad_30d_p25', 'avg_pad_30d_p50', 'avg_pad_30d_p75']
# ['avg_pad_30d_p90', 'avg_pad_30d_p95', 'avg_pad_60d_mean', 'avg_pad_60d_min', 'avg_pad_60d_max']
# ['avg_pad_60d_std', 'avg_pad_60d_var', 'avg_pad_60d_p25', 'avg_pad_60d_p50', 'avg_pad_60d_p75']
# ['avg_pad_60d_p90', 'avg_pad_60d_p95', 'avg_pad_90d_mean', 'avg_pad_90d_min', 'avg_pad_90d_max']
# ['avg_pad_90d_std', 'avg_pad_90d_var', 'avg_pad_90d_p25', 'avg_pad_90d_p50', 'avg_pad_90d_p75']
# ['avg_pad_90d_p90', 'avg_pad_90d_p95', 'min_pad_2d_mean', 'min_pad_2d_min', 'min_pad_2d_max']
# ['min_pad_2d_std', 'min_pad_2d_var', 'min_pad_2d_p25', 'min_pad_2d_p50', 'min_pad_2d_p75']
# ['min_pad_2d_p90', 'min_pad_2d_p95', 'min_pad_3d_mean', 'min_pad_3d_min', 'min_pad_3d_max']
# ['min_pad_3d_std', 'min_pad_3d_var', 'min_pad_3d_p25', 'min_pad_3d_p50', 'min_pad_3d_p75']
# ['min_pad_3d_p90', 'min_pad_3d_p95', 'min_pad_7d_mean', 'min_pad_7d_min', 'min_pad_7d_max']
# ['min_pad_7d_std', 'min_pad_7d_var', 'min_pad_7d_p25', 'min_pad_7d_p50', 'min_pad_7d_p75']
# ['min_pad_7d_p90', 'min_pad_7d_p95', 'min_pad_30d_mean', 'min_pad_30d_min', 'min_pad_30d_max']
# ['min_pad_30d_std', 'min_pad_30d_var', 'min_pad_30d_p25', 'min_pad_30d_p50', 'min_pad_30d_p75']
# ['min_pad_30d_p90', 'min_pad_30d_p95', 'min_pad_60d_mean', 'min_pad_60d_min', 'min_pad_60d_max']
# ['min_pad_60d_std', 'min_pad_60d_var', 'min_pad_60d_p25', 'min_pad_60d_p50', 'min_pad_60d_p75']
# ['min_pad_60d_p90', 'min_pad_60d_p95', 'min_pad_90d_mean', 'min_pad_90d_min', 'min_pad_90d_max']
# ['min_pad_90d_std', 'min_pad_90d_var', 'min_pad_90d_p25', 'min_pad_90d_p50', 'min_pad_90d_p75']
# ['min_pad_90d_p90', 'min_pad_90d_p95', 'max_pad_2d_mean', 'max_pad_2d_min', 'max_pad_2d_max']
# ['max_pad_2d_std', 'max_pad_2d_var', 'max_pad_2d_p25', 'max_pad_2d_p50', 'max_pad_2d_p75']
# ['max_pad_2d_p90', 'max_pad_2d_p95', 'max_pad_3d_mean', 'max_pad_3d_min', 'max_pad_3d_max']
# ['max_pad_3d_std', 'max_pad_3d_var', 'max_pad_3d_p25', 'max_pad_3d_p50', 'max_pad_3d_p75']
# ['max_pad_3d_p90', 'max_pad_3d_p95', 'max_pad_7d_mean', 'max_pad_7d_min', 'max_pad_7d_max']
# ['max_pad_7d_std', 'max_pad_7d_var', 'max_pad_7d_p25', 'max_pad_7d_p50', 'max_pad_7d_p75']
# ['max_pad_7d_p90', 'max_pad_7d_p95', 'max_pad_30d_mean', 'max_pad_30d_min', 'max_pad_30d_max']
# ['max_pad_30d_std', 'max_pad_30d_var', 'max_pad_30d_p25', 'max_pad_30d_p50', 'max_pad_30d_p75']
# ['max_pad_30d_p90', 'max_pad_30d_p95', 'max_pad_60d_mean', 'max_pad_60d_min', 'max_pad_60d_max']
# ['max_pad_60d_std', 'max_pad_60d_var', 'max_pad_60d_p25', 'max_pad_60d_p50', 'max_pad_60d_p75']
# ['max_pad_60d_p90', 'max_pad_60d_p95', 'max_pad_90d_mean', 'max_pad_90d_min', 'max_pad_90d_max']
# ['max_pad_90d_std', 'max_pad_90d_var', 'max_pad_90d_p25', 'max_pad_90d_p50', 'max_pad_90d_p75']
# ['max_pad_90d_p90', 'max_pad_90d_p95', 'total_pc_2d_mean', 'total_pc_2d_min', 'total_pc_2d_max']
# ['total_pc_2d_std', 'total_pc_2d_var', 'total_pc_2d_p25', 'total_pc_2d_p50', 'total_pc_2d_p75']
# ['total_pc_2d_p90', 'total_pc_2d_p95', 'total_pc_3d_mean', 'total_pc_3d_min', 'total_pc_3d_max']
# ['total_pc_3d_std', 'total_pc_3d_var', 'total_pc_3d_p25', 'total_pc_3d_p50', 'total_pc_3d_p75']
# ['total_pc_3d_p90', 'total_pc_3d_p95', 'total_pc_7d_mean', 'total_pc_7d_min', 'total_pc_7d_max']
# ['total_pc_7d_std', 'total_pc_7d_var', 'total_pc_7d_p25', 'total_pc_7d_p50', 'total_pc_7d_p75']
# ['total_pc_7d_p90', 'total_pc_7d_p95', 'total_pc_30d_mean', 'total_pc_30d_min', 'total_pc_30d_max']
# ['total_pc_30d_std', 'total_pc_30d_var', 'total_pc_30d_p25', 'total_pc_30d_p50', 'total_pc_30d_p75']
# ['total_pc_30d_p90', 'total_pc_30d_p95', 'total_pc_60d_mean', 'total_pc_60d_min', 'total_pc_60d_max']
# ['total_pc_60d_std', 'total_pc_60d_var', 'total_pc_60d_p25', 'total_pc_60d_p50', 'total_pc_60d_p75']
# ['total_pc_60d_p90', 'total_pc_60d_p95', 'total_pc_90d_mean', 'total_pc_90d_min', 'total_pc_90d_max']
# ['total_pc_90d_std', 'total_pc_90d_var', 'total_pc_90d_p25', 'total_pc_90d_p50', 'total_pc_90d_p75']
# ['total_pc_90d_p90', 'total_pc_90d_p95', 'avg_pc_2d_mean', 'avg_pc_2d_min', 'avg_pc_2d_max']
# ['avg_pc_2d_std', 'avg_pc_2d_var', 'avg_pc_2d_p25', 'avg_pc_2d_p50', 'avg_pc_2d_p75']
# ['avg_pc_2d_p90', 'avg_pc_2d_p95', 'avg_pc_3d_mean', 'avg_pc_3d_min', 'avg_pc_3d_max']
# ['avg_pc_3d_std', 'avg_pc_3d_var', 'avg_pc_3d_p25', 'avg_pc_3d_p50', 'avg_pc_3d_p75']
# ['avg_pc_3d_p90', 'avg_pc_3d_p95', 'avg_pc_7d_mean', 'avg_pc_7d_min', 'avg_pc_7d_max']
# ['avg_pc_7d_std', 'avg_pc_7d_var', 'avg_pc_7d_p25', 'avg_pc_7d_p50', 'avg_pc_7d_p75']
# ['avg_pc_7d_p90', 'avg_pc_7d_p95', 'avg_pc_30d_mean', 'avg_pc_30d_min', 'avg_pc_30d_max']
# ['avg_pc_30d_std', 'avg_pc_30d_var', 'avg_pc_30d_p25', 'avg_pc_30d_p50', 'avg_pc_30d_p75']
# ['avg_pc_30d_p90', 'avg_pc_30d_p95', 'avg_pc_60d_mean', 'avg_pc_60d_min', 'avg_pc_60d_max']
# ['avg_pc_60d_std', 'avg_pc_60d_var', 'avg_pc_60d_p25', 'avg_pc_60d_p50', 'avg_pc_60d_p75']
# ['avg_pc_60d_p90', 'avg_pc_60d_p95', 'avg_pc_90d_mean', 'avg_pc_90d_min', 'avg_pc_90d_max']
# ['avg_pc_90d_std', 'avg_pc_90d_var', 'avg_pc_90d_p25', 'avg_pc_90d_p50', 'avg_pc_90d_p75']
# ['avg_pc_90d_p90', 'avg_pc_90d_p95', 'min_pc_2d_mean', 'min_pc_2d_min', 'min_pc_2d_max']
# ['min_pc_2d_std', 'min_pc_2d_var', 'min_pc_2d_p25', 'min_pc_2d_p50', 'min_pc_2d_p75']
# ['min_pc_2d_p90', 'min_pc_2d_p95', 'min_pc_3d_mean', 'min_pc_3d_min', 'min_pc_3d_max']
# ['min_pc_3d_std', 'min_pc_3d_var', 'min_pc_3d_p25', 'min_pc_3d_p50', 'min_pc_3d_p75']
# ['min_pc_3d_p90', 'min_pc_3d_p95', 'min_pc_7d_mean', 'min_pc_7d_min', 'min_pc_7d_max']
# ['min_pc_7d_std', 'min_pc_7d_var', 'min_pc_7d_p25', 'min_pc_7d_p50', 'min_pc_7d_p75']
# ['min_pc_7d_p90', 'min_pc_7d_p95', 'min_pc_30d_mean', 'min_pc_30d_min', 'min_pc_30d_max']
# ['min_pc_30d_std', 'min_pc_30d_var', 'min_pc_30d_p25', 'min_pc_30d_p50', 'min_pc_30d_p75']
# ['min_pc_30d_p90', 'min_pc_30d_p95', 'min_pc_60d_mean', 'min_pc_60d_min', 'min_pc_60d_max']
# ['min_pc_60d_std', 'min_pc_60d_var', 'min_pc_60d_p25', 'min_pc_60d_p50', 'min_pc_60d_p75']
# ['min_pc_60d_p90', 'min_pc_60d_p95', 'min_pc_90d_mean', 'min_pc_90d_min', 'min_pc_90d_max']
# ['min_pc_90d_std', 'min_pc_90d_var', 'min_pc_90d_p25', 'min_pc_90d_p50', 'min_pc_90d_p75']
# ['min_pc_90d_p90', 'min_pc_90d_p95', 'max_pc_2d_mean', 'max_pc_2d_min', 'max_pc_2d_max']
# ['max_pc_2d_std', 'max_pc_2d_var', 'max_pc_2d_p25', 'max_pc_2d_p50', 'max_pc_2d_p75']
# ['max_pc_2d_p90', 'max_pc_2d_p95', 'max_pc_3d_mean', 'max_pc_3d_min', 'max_pc_3d_max']
# ['max_pc_3d_std', 'max_pc_3d_var', 'max_pc_3d_p25', 'max_pc_3d_p50', 'max_pc_3d_p75']
# ['max_pc_3d_p90', 'max_pc_3d_p95', 'max_pc_7d_mean', 'max_pc_7d_min', 'max_pc_7d_max']
# ['max_pc_7d_std', 'max_pc_7d_var', 'max_pc_7d_p25', 'max_pc_7d_p50', 'max_pc_7d_p75']
# ['max_pc_7d_p90', 'max_pc_7d_p95', 'max_pc_30d_mean', 'max_pc_30d_min', 'max_pc_30d_max']
# ['max_pc_30d_std', 'max_pc_30d_var', 'max_pc_30d_p25', 'max_pc_30d_p50', 'max_pc_30d_p75']
# ['max_pc_30d_p90', 'max_pc_30d_p95', 'max_pc_60d_mean', 'max_pc_60d_min', 'max_pc_60d_max']
# ['max_pc_60d_std', 'max_pc_60d_var', 'max_pc_60d_p25', 'max_pc_60d_p50', 'max_pc_60d_p75']
# ['max_pc_60d_p90', 'max_pc_60d_p95', 'max_pc_90d_mean', 'max_pc_90d_min', 'max_pc_90d_max']
# ['max_pc_90d_std', 'max_pc_90d_var', 'max_pc_90d_p25', 'max_pc_90d_p50', 'max_pc_90d_p75']
# ['max_pc_90d_p90', 'max_pc_90d_p95', 'total_pd_2d_mean', 'total_pd_2d_min', 'total_pd_2d_max']
# ['total_pd_2d_std', 'total_pd_2d_var', 'total_pd_2d_p25', 'total_pd_2d_p50', 'total_pd_2d_p75']
# ['total_pd_2d_p90', 'total_pd_2d_p95', 'total_pd_3d_mean', 'total_pd_3d_min', 'total_pd_3d_max']
# ['total_pd_3d_std', 'total_pd_3d_var', 'total_pd_3d_p25', 'total_pd_3d_p50', 'total_pd_3d_p75']
# ['total_pd_3d_p90', 'total_pd_3d_p95', 'total_pd_7d_mean', 'total_pd_7d_min', 'total_pd_7d_max']
# ['total_pd_7d_std', 'total_pd_7d_var', 'total_pd_7d_p25', 'total_pd_7d_p50', 'total_pd_7d_p75']
# ['total_pd_7d_p90', 'total_pd_7d_p95', 'total_pd_30d_mean', 'total_pd_30d_min', 'total_pd_30d_max']
# ['total_pd_30d_std', 'total_pd_30d_var', 'total_pd_30d_p25', 'total_pd_30d_p50', 'total_pd_30d_p75']
# ['total_pd_30d_p90', 'total_pd_30d_p95', 'total_pd_60d_mean', 'total_pd_60d_min', 'total_pd_60d_max']
# ['total_pd_60d_std', 'total_pd_60d_var', 'total_pd_60d_p25', 'total_pd_60d_p50', 'total_pd_60d_p75']
# ['total_pd_60d_p90', 'total_pd_60d_p95', 'total_pd_90d_mean', 'total_pd_90d_min', 'total_pd_90d_max']
# ['total_pd_90d_std', 'total_pd_90d_var', 'total_pd_90d_p25', 'total_pd_90d_p50', 'total_pd_90d_p75']
# ['total_pd_90d_p90', 'total_pd_90d_p95', 'avg_pd_2d_mean', 'avg_pd_2d_min', 'avg_pd_2d_max']
# ['avg_pd_2d_std', 'avg_pd_2d_var', 'avg_pd_2d_p25', 'avg_pd_2d_p50', 'avg_pd_2d_p75']
# ['avg_pd_2d_p90', 'avg_pd_2d_p95', 'avg_pd_3d_mean', 'avg_pd_3d_min', 'avg_pd_3d_max']
# ['avg_pd_3d_std', 'avg_pd_3d_var', 'avg_pd_3d_p25', 'avg_pd_3d_p50', 'avg_pd_3d_p75']
# ['avg_pd_3d_p90', 'avg_pd_3d_p95', 'avg_pd_7d_mean', 'avg_pd_7d_min', 'avg_pd_7d_max']
# ['avg_pd_7d_std', 'avg_pd_7d_var', 'avg_pd_7d_p25', 'avg_pd_7d_p50', 'avg_pd_7d_p75']
# ['avg_pd_7d_p90', 'avg_pd_7d_p95', 'avg_pd_30d_mean', 'avg_pd_30d_min', 'avg_pd_30d_max']
# ['avg_pd_30d_std', 'avg_pd_30d_var', 'avg_pd_30d_p25', 'avg_pd_30d_p50', 'avg_pd_30d_p75']
# ['avg_pd_30d_p90', 'avg_pd_30d_p95', 'avg_pd_60d_mean', 'avg_pd_60d_min', 'avg_pd_60d_max']
# ['avg_pd_60d_std', 'avg_pd_60d_var', 'avg_pd_60d_p25', 'avg_pd_60d_p50', 'avg_pd_60d_p75']
# ['avg_pd_60d_p90', 'avg_pd_60d_p95', 'avg_pd_90d_mean', 'avg_pd_90d_min', 'avg_pd_90d_max']
# ['avg_pd_90d_std', 'avg_pd_90d_var', 'avg_pd_90d_p25', 'avg_pd_90d_p50', 'avg_pd_90d_p75']
# ['avg_pd_90d_p90', 'avg_pd_90d_p95', 'min_pd_2d_mean', 'min_pd_2d_min', 'min_pd_2d_max']
# ['min_pd_2d_std', 'min_pd_2d_var', 'min_pd_2d_p25', 'min_pd_2d_p50', 'min_pd_2d_p75']
# ['min_pd_2d_p90', 'min_pd_2d_p95', 'min_pd_3d_mean', 'min_pd_3d_min', 'min_pd_3d_max']
# ['min_pd_3d_std', 'min_pd_3d_var', 'min_pd_3d_p25', 'min_pd_3d_p50', 'min_pd_3d_p75']
# ['min_pd_3d_p90', 'min_pd_3d_p95', 'min_pd_7d_mean', 'min_pd_7d_min', 'min_pd_7d_max']
# ['min_pd_7d_std', 'min_pd_7d_var', 'min_pd_7d_p25', 'min_pd_7d_p50', 'min_pd_7d_p75']
# ['min_pd_7d_p90', 'min_pd_7d_p95', 'min_pd_30d_mean', 'min_pd_30d_min', 'min_pd_30d_max']
# ['min_pd_30d_std', 'min_pd_30d_var', 'min_pd_30d_p25', 'min_pd_30d_p50', 'min_pd_30d_p75']
# ['min_pd_30d_p90', 'min_pd_30d_p95', 'min_pd_60d_mean', 'min_pd_60d_min', 'min_pd_60d_max']
# ['min_pd_60d_std', 'min_pd_60d_var', 'min_pd_60d_p25', 'min_pd_60d_p50', 'min_pd_60d_p75']
# ['min_pd_60d_p90', 'min_pd_60d_p95', 'min_pd_90d_mean', 'min_pd_90d_min', 'min_pd_90d_max']
# ['min_pd_90d_std', 'min_pd_90d_var', 'min_pd_90d_p25', 'min_pd_90d_p50', 'min_pd_90d_p75']
# ['min_pd_90d_p90', 'min_pd_90d_p95', 'max_pd_2d_mean', 'max_pd_2d_min', 'max_pd_2d_max']
# ['max_pd_2d_std', 'max_pd_2d_var', 'max_pd_2d_p25', 'max_pd_2d_p50', 'max_pd_2d_p75']
# ['max_pd_2d_p90', 'max_pd_2d_p95', 'max_pd_3d_mean', 'max_pd_3d_min', 'max_pd_3d_max']
# ['max_pd_3d_std', 'max_pd_3d_var', 'max_pd_3d_p25', 'max_pd_3d_p50', 'max_pd_3d_p75']
# ['max_pd_3d_p90', 'max_pd_3d_p95', 'max_pd_7d_mean', 'max_pd_7d_min', 'max_pd_7d_max']
# ['max_pd_7d_std', 'max_pd_7d_var', 'max_pd_7d_p25', 'max_pd_7d_p50', 'max_pd_7d_p75']
# ['max_pd_7d_p90', 'max_pd_7d_p95', 'max_pd_30d_mean', 'max_pd_30d_min', 'max_pd_30d_max']
# ['max_pd_30d_std', 'max_pd_30d_var', 'max_pd_30d_p25', 'max_pd_30d_p50', 'max_pd_30d_p75']
# ['max_pd_30d_p90', 'max_pd_30d_p95', 'max_pd_60d_mean', 'max_pd_60d_min', 'max_pd_60d_max']
# ['max_pd_60d_std', 'max_pd_60d_var', 'max_pd_60d_p25', 'max_pd_60d_p50', 'max_pd_60d_p75']
# ['max_pd_60d_p90', 'max_pd_60d_p95', 'max_pd_90d_mean', 'max_pd_90d_min', 'max_pd_90d_max']
# ['max_pd_90d_std', 'max_pd_90d_var', 'max_pd_90d_p25', 'max_pd_90d_p50', 'max_pd_90d_p75']
# ['max_pd_90d_p90', 'max_pd_90d_p95', 'total_pp_2d_mean', 'total_pp_2d_min', 'total_pp_2d_max']
# ['total_pp_2d_std', 'total_pp_2d_var', 'total_pp_2d_p25', 'total_pp_2d_p50', 'total_pp_2d_p75']
# ['total_pp_2d_p90', 'total_pp_2d_p95', 'total_pp_3d_mean', 'total_pp_3d_min', 'total_pp_3d_max']
# ['total_pp_3d_std', 'total_pp_3d_var', 'total_pp_3d_p25', 'total_pp_3d_p50', 'total_pp_3d_p75']
# ['total_pp_3d_p90', 'total_pp_3d_p95', 'total_pp_7d_mean', 'total_pp_7d_min', 'total_pp_7d_max']
# ['total_pp_7d_std', 'total_pp_7d_var', 'total_pp_7d_p25', 'total_pp_7d_p50', 'total_pp_7d_p75']
# ['total_pp_7d_p90', 'total_pp_7d_p95', 'total_pp_30d_mean', 'total_pp_30d_min', 'total_pp_30d_max']
# ['total_pp_30d_std', 'total_pp_30d_var', 'total_pp_30d_p25', 'total_pp_30d_p50', 'total_pp_30d_p75']
# ['total_pp_30d_p90', 'total_pp_30d_p95', 'total_pp_60d_mean', 'total_pp_60d_min', 'total_pp_60d_max']
# ['total_pp_60d_std', 'total_pp_60d_var', 'total_pp_60d_p25', 'total_pp_60d_p50', 'total_pp_60d_p75']
# ['total_pp_60d_p90', 'total_pp_60d_p95', 'total_pp_90d_mean', 'total_pp_90d_min', 'total_pp_90d_max']
# ['total_pp_90d_std', 'total_pp_90d_var', 'total_pp_90d_p25', 'total_pp_90d_p50', 'total_pp_90d_p75']
# ['total_pp_90d_p90', 'total_pp_90d_p95', 'avg_pp_2d_mean', 'avg_pp_2d_min', 'avg_pp_2d_max']
# ['avg_pp_2d_std', 'avg_pp_2d_var', 'avg_pp_2d_p25', 'avg_pp_2d_p50', 'avg_pp_2d_p75']
# ['avg_pp_2d_p90', 'avg_pp_2d_p95', 'avg_pp_3d_mean', 'avg_pp_3d_min', 'avg_pp_3d_max']
# ['avg_pp_3d_std', 'avg_pp_3d_var', 'avg_pp_3d_p25', 'avg_pp_3d_p50', 'avg_pp_3d_p75']
# ['avg_pp_3d_p90', 'avg_pp_3d_p95', 'avg_pp_7d_mean', 'avg_pp_7d_min', 'avg_pp_7d_max']
# ['avg_pp_7d_std', 'avg_pp_7d_var', 'avg_pp_7d_p25', 'avg_pp_7d_p50', 'avg_pp_7d_p75']
# ['avg_pp_7d_p90', 'avg_pp_7d_p95', 'avg_pp_30d_mean', 'avg_pp_30d_min', 'avg_pp_30d_max']
# ['avg_pp_30d_std', 'avg_pp_30d_var', 'avg_pp_30d_p25', 'avg_pp_30d_p50', 'avg_pp_30d_p75']
# ['avg_pp_30d_p90', 'avg_pp_30d_p95', 'avg_pp_60d_mean', 'avg_pp_60d_min', 'avg_pp_60d_max']
# ['avg_pp_60d_std', 'avg_pp_60d_var', 'avg_pp_60d_p25', 'avg_pp_60d_p50', 'avg_pp_60d_p75']
# ['avg_pp_60d_p90', 'avg_pp_60d_p95', 'avg_pp_90d_mean', 'avg_pp_90d_min', 'avg_pp_90d_max']
# ['avg_pp_90d_std', 'avg_pp_90d_var', 'avg_pp_90d_p25', 'avg_pp_90d_p50', 'avg_pp_90d_p75']
# ['avg_pp_90d_p90', 'avg_pp_90d_p95', 'min_pp_2d_mean', 'min_pp_2d_min', 'min_pp_2d_max']
# ['min_pp_2d_std', 'min_pp_2d_var', 'min_pp_2d_p25', 'min_pp_2d_p50', 'min_pp_2d_p75']
# ['min_pp_2d_p90', 'min_pp_2d_p95', 'min_pp_3d_mean', 'min_pp_3d_min', 'min_pp_3d_max']
# ['min_pp_3d_std', 'min_pp_3d_var', 'min_pp_3d_p25', 'min_pp_3d_p50', 'min_pp_3d_p75']
# ['min_pp_3d_p90', 'min_pp_3d_p95', 'min_pp_7d_mean', 'min_pp_7d_min', 'min_pp_7d_max']
# ['min_pp_7d_std', 'min_pp_7d_var', 'min_pp_7d_p25', 'min_pp_7d_p50', 'min_pp_7d_p75']
# ['min_pp_7d_p90', 'min_pp_7d_p95', 'min_pp_30d_mean', 'min_pp_30d_min', 'min_pp_30d_max']
# ['min_pp_30d_std', 'min_pp_30d_var', 'min_pp_30d_p25', 'min_pp_30d_p50', 'min_pp_30d_p75']
# ['min_pp_30d_p90', 'min_pp_30d_p95', 'min_pp_60d_mean', 'min_pp_60d_min', 'min_pp_60d_max']
# ['min_pp_60d_std', 'min_pp_60d_var', 'min_pp_60d_p25', 'min_pp_60d_p50', 'min_pp_60d_p75']
# ['min_pp_60d_p90', 'min_pp_60d_p95', 'min_pp_90d_mean', 'min_pp_90d_min', 'min_pp_90d_max']
# ['min_pp_90d_std', 'min_pp_90d_var', 'min_pp_90d_p25', 'min_pp_90d_p50', 'min_pp_90d_p75']
# ['min_pp_90d_p90', 'min_pp_90d_p95', 'max_pp_2d_mean', 'max_pp_2d_min', 'max_pp_2d_max']
# ['max_pp_2d_std', 'max_pp_2d_var', 'max_pp_2d_p25', 'max_pp_2d_p50', 'max_pp_2d_p75']
# ['max_pp_2d_p90', 'max_pp_2d_p95', 'max_pp_3d_mean', 'max_pp_3d_min', 'max_pp_3d_max']
# ['max_pp_3d_std', 'max_pp_3d_var', 'max_pp_3d_p25', 'max_pp_3d_p50', 'max_pp_3d_p75']
# ['max_pp_3d_p90', 'max_pp_3d_p95', 'max_pp_7d_mean', 'max_pp_7d_min', 'max_pp_7d_max']
# ['max_pp_7d_std', 'max_pp_7d_var', 'max_pp_7d_p25', 'max_pp_7d_p50', 'max_pp_7d_p75']
# ['max_pp_7d_p90', 'max_pp_7d_p95', 'max_pp_30d_mean', 'max_pp_30d_min', 'max_pp_30d_max']
# ['max_pp_30d_std', 'max_pp_30d_var', 'max_pp_30d_p25', 'max_pp_30d_p50', 'max_pp_30d_p75']
# ['max_pp_30d_p90', 'max_pp_30d_p95', 'max_pp_60d_mean', 'max_pp_60d_min', 'max_pp_60d_max']
# ['max_pp_60d_std', 'max_pp_60d_var', 'max_pp_60d_p25', 'max_pp_60d_p50', 'max_pp_60d_p75']
# ['max_pp_60d_p90', 'max_pp_60d_p95', 'max_pp_90d_mean', 'max_pp_90d_min', 'max_pp_90d_max']
# ['max_pp_90d_std', 'max_pp_90d_var', 'max_pp_90d_p25', 'max_pp_90d_p50', 'max_pp_90d_p75']
# ['max_pp_90d_p90', 'max_pp_90d_p95']
