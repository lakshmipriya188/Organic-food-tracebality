# %%
import pandas as pd
import numpy as np
import seaborn as sms
import matplotlib.pyplot as plt

# %%
sales= pd.read_csv("sales_date.csv")

# %%
sales.head()
# Out:
#    order_id  customer_id  product_id  product_count  product_price  \
# 0         6        28663         413              8        95.4065
# 1         7        46674         370             12        21.8806
# 2        15        19310         134              5        39.8545
# 3        16        91867         364             24         8.8429
# 4        17        14612         185              4        48.4195
#
#    product_discount  price_after_discount  order_date
# 0                 5                 90.64  2026-02-07
# 1                10                 19.69  2026-03-02
# 2                 6                 37.46  2026-01-26
# 3                28                  6.37  2026-04-30
# 4                19                 39.22  2026-01-20

# %%
c= pd.read_csv("Customer.csv",index_col=0)

# %%
c.head()
# Out:
#    customer_id FirstName MiddleName LastName                       Address  \
# 0            1  Stefanie          Y     Frye                 97 Oak Avenue
# 1            2     Sandy          T    Kirby        52 White First Freeway
# 2            3       Lee          T    Zhang       921 White Fabien Avenue
# 3            4    Regina          S    Avery                 75 Old Avenue
# 4            5    Daniel          S   Mccann  283 South Green Hague Avenue
#
#      customer_name         email_id password
# 0  Stefanie Y Frye  stee1@gmail.com    1eets
# 1    Sandy T Kirby  sany2@gmail.com    2ynas
# 2      Lee T Zhang  leeg3@gmail.com    3geel
# 3   Regina S Avery  regy4@gmail.com    4yger
# 4  Daniel S Mccann  dann5@gmail.com    5nnad

# %%
df = sales.merge(
    c[['customer_id']],
    on = ['customer_id'],
    how='inner'
)

# %%
df.shape
# Out:
# (1509835, 8)

# %%
df.head()
# Out:
#    order_id  customer_id  product_id  product_count  product_price  \
# 0         6        28663         413              8        95.4065
# 1         7        46674         370             12        21.8806
# 2        15        19310         134              5        39.8545
# 3        16        91867         364             24         8.8429
# 4        17        14612         185              4        48.4195
#
#    product_discount  price_after_discount  order_date
# 0                 5                 90.64  2026-02-07
# 1                10                 19.69  2026-03-02
# 2                 6                 37.46  2026-01-26
# 3                28                  6.37  2026-04-30
# 4                19                 39.22  2026-01-20

# %%
import pandas as pd

# Make sure order_date is datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Calculate spend for each transaction
df['spend'] = df['product_count'] * df['price_after_discount']

# Aggregate at Customer + Product + Date level
customer_product_date = (
    df.groupby(['customer_id', 'product_id', 'order_date'])
      .agg(
          purchase_count=('order_id', 'nunique'),
          total_quantity=('product_count', 'sum'),
          avg_quantity=('product_count', 'mean'),
          total_spend=('spend', 'sum'),
          avg_discount=('product_discount', 'mean')
      )
      .reset_index()
)

customer_product_date.sample(20)
# Out:
#          customer_id  product_id order_date  purchase_count  total_quantity  \
# 746157         49323         153 2026-01-19               1              13
# 811909         53670         370 2026-01-04               1              14
# 780913         51609         425 2026-04-27               1              14
# 205363         13582         429 2026-03-24               1               4
# 1011432        66865          60 2026-02-13               1              17
# 1184961        78343         319 2026-01-02               1              20
# 233758         15455           8 2026-05-04               1               4
# 161552         10675         298 2026-02-13               1               3
# 600933         39736         298 2026-01-09               1              11
# 1193929        78930          32 2026-05-01               1              20
# 342847         22649           8 2026-02-26               1               6
# 224413         14839         359 2026-02-21               1               4
# 1163686        76937         281 2026-01-13               1              20
# 814052         53810          94 2026-01-10               1              14
# 456246         30182         331 2026-03-18               1               8
# 22500           1475         319 2026-04-18               1               1
# 789879         52199          12 2026-03-25               1              14
# 853751         56429           7 2026-02-10               1              15
# 964240         63728         192 2026-01-22               1              17
# 258331         17076         432 2026-03-15               1               5
#
#          avg_quantity  total_spend  avg_discount
# 746157           13.0       785.20          14.0
# 811909           14.0       275.66          10.0
# 780913           14.0       707.56          11.0
# 205363            4.0       211.96           8.0
# 1011432          17.0       463.42          14.0
# 1184961          20.0      1257.40          19.0
# 233758            4.0       258.80          28.0
# 161552            3.0       269.97           6.0
# 600933           11.0       989.89           6.0
# 1193929          20.0      1465.40          24.0
# 342847            6.0       388.20          28.0
# 224413            4.0       193.28          30.0
# 1163686          20.0       502.80          24.0
# 814052           14.0       487.34          20.0
# 456246            8.0       463.36          14.0
# 22500             1.0        62.87          19.0
# 789879           14.0       518.00          25.0
# 853751           15.0       358.20          25.0
# 964240           17.0       402.39          20.0
# 258331            5.0       124.30          24.0
