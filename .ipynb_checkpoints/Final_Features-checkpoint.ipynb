# %%
import pandas as pd
import numpy as np
sales= pd.read_csv("sales_date.csv")
sales.dropna(inplace= True)
sales.isnull().sum()
# Out:
# order_id                0
# customer_id             0
# product_id              0
# product_count           0
# product_price           0
# product_discount        0
# price_after_discount    0
# order_date              0
# dtype: int64

# %%
sales.shape
# Out:
# (1494806, 8)

# %%
sales.groupby('customer_id').size().sort_values(ascending=False).reset_index(name='order_count').head()
# Out:
#    customer_id  order_count
# 0        40880           36
# 1        24271           32
# 2        94904           32
# 3        97967           32
# 4        72034           32

# %% [markdown]
# # Feature Creation Cus*order_date ---------- Product ------

# %%
df = sales[sales["customer_id"] == 24271].copy()
df["order_date"] = pd.to_datetime(df["order_date"])
df["day_of_week"] = df["order_date"].dt.dayofweek
df["day_of_month"] = df["order_date"].dt.day
df["month"] = df["order_date"].dt.month
df["quarter"] = df["order_date"].dt.quarter
df["week_of_year"] = df["order_date"].dt.isocalendar().week
df["is_weekend"] = df["day_of_week"].isin([5, 6]).astype(int)

# %%
df['spend'] =df['price_after_discount']*df['product_count']
df.head()
# Out:
#         order_id  customer_id  product_id  product_count  product_price  \
# 98010     438718        24271         419              7        86.1338
# 112480    503978        24271         197              7        13.0101
# 115255    516091        24271         419              7        86.1338
# 126923    568310        24271         231              7        68.3066
# 161654    722042        24271         319              7        77.6195
#
#         product_discount  price_after_discount order_date  day_of_week  \
# 98010                 21                 68.05 2026-01-10            5
# 112480                16                 10.93 2026-03-15            6
# 115255                21                 68.05 2026-04-18            5
# 126923                17                 56.69 2026-04-14            1
# 161654                19                 62.87 2026-02-18            2
#
#         day_of_month  month  quarter  week_of_year  is_weekend   spend
# 98010             10      1        1             2           1  476.35
# 112480            15      3        1            11           1   76.51
# 115255            18      4        2            16           1  476.35
# 126923            14      4        2            16           0  396.83
# 161654            18      2        1             8           0  440.09

# %%
df.shape
# Out:
# (32, 15)

# %%
cpd = (
    df.groupby(
        ["customer_id", "order_date"],
        as_index=False
    )
    .agg(
        purchase_count=("order_id", "count"),

        # Quantity
        avg_quantity=("product_count", "mean"),
        max_quantity=("product_count", "max"),
        p25_quantity=("product_count", lambda x: x.quantile(0.25)),
        p50_quantity=("product_count", lambda x: x.quantile(0.50)),
        p75_quantity=("product_count", lambda x: x.quantile(0.75)),
        p90_quantity=("product_count", lambda x: x.quantile(0.90)),
        p95_quantity=("product_count", lambda x: x.quantile(0.95)),

        # Spend
        total_spend=("spend", "sum"),
        avg_spend=("spend", "mean"),
        min_spend=("spend", "min"),
        max_spend=("spend", "max"),
        p25_spend=("spend", lambda x: x.quantile(0.25)),
        p50_spend=("spend", lambda x: x.quantile(0.50)),
        p75_spend=("spend", lambda x: x.quantile(0.75)),
        p90_spend=("spend", lambda x: x.quantile(0.90)),
        p95_spend=("spend", lambda x: x.quantile(0.95)),

        # Price after discount
        total_pad=("price_after_discount", "sum"),
        avg_pad=("price_after_discount", "mean"),
        min_pad=("price_after_discount", "min"),
        max_pad=("price_after_discount", "max"),
        p25_pad=("price_after_discount", lambda x: x.quantile(0.25)),
        p50_pad=("price_after_discount", lambda x: x.quantile(0.50)),
        p75_pad=("price_after_discount", lambda x: x.quantile(0.75)),
        p90_pad=("price_after_discount", lambda x: x.quantile(0.90)),
        p95_pad=("price_after_discount", lambda x: x.quantile(0.95)),

        # Product count
        total_pc=("product_count", "sum"),
        avg_pc=("product_count", "mean"),
        min_pc=("product_count", "min"),
        max_pc=("product_count", "max"),
        p25_pc=("product_count", lambda x: x.quantile(0.25)),
        p50_pc=("product_count", lambda x: x.quantile(0.50)),
        p75_pc=("product_count", lambda x: x.quantile(0.75)),
        p90_pc=("product_count", lambda x: x.quantile(0.90)),
        p95_pc=("product_count", lambda x: x.quantile(0.95)),

        # Product discount
        total_pd=("product_discount", "sum"),
        avg_pd=("product_discount", "mean"),
        min_pd=("product_discount", "min"),
        max_pd=("product_discount", "max"),
        p25_pd=("product_discount", lambda x: x.quantile(0.25)),
        p50_pd=("product_discount", lambda x: x.quantile(0.50)),
        p75_pd=("product_discount", lambda x: x.quantile(0.75)),
        p90_pd=("product_discount", lambda x: x.quantile(0.90)),
        p95_pd=("product_discount", lambda x: x.quantile(0.95)),
        
        # Product price
        total_pp=("product_price", "sum"),
        avg_pp=("product_price", "mean"),
        min_pp=("product_price", "min"),
        max_pp=("product_price", "max"),
        p25_pp=("product_price", lambda x: x.quantile(0.25)),
        p50_pp=("product_price", lambda x: x.quantile(0.50)),
        p75_pp=("product_price", lambda x: x.quantile(0.75)),
        p90_pp=("product_price", lambda x: x.quantile(0.90)),
        p95_pp=("product_price", lambda x: x.quantile(0.95)),
        
        mode_product_id=("product_id", lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan),
    )
)

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {(cpd.shape)}")
print("=" * 100)
for i in range(0, len(columns), 10):
    print(columns[i:i+10].tolist())
# Out:
# ====================================================================================================
# Total columns: (27, 56)
# ====================================================================================================
# ['avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend', 'min_spend']
# ['max_spend', 'p25_spend', 'p50_spend', 'p75_spend', 'p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad', 'max_pad']
# ['p25_pad', 'p50_pad', 'p75_pad', 'p90_pad', 'p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc', 'p25_pc']
# ['p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 'total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd', 'p50_pd']
# ['p75_pd', 'p90_pd', 'p95_pd', 'total_pp', 'avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp', 'p75_pp']
# ['p90_pp', 'p95_pp', 'mode_product_id']

# %%
cpd = cpd.sort_values( ["customer_id", "order_date"]).copy()
for i in cpd.columns:
    cpd[f"last_{i}"] = (cpd.groupby("customer_id")[i] .shift(1) )

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {(cpd.shape)}")
print("=" * 100)
for i in range(0, len(columns), 10):
    print(columns[i:i+10].tolist())
# Out:
# ====================================================================================================
# Total columns: (27, 112)
# ====================================================================================================
# ['avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend', 'min_spend']
# ['max_spend', 'p25_spend', 'p50_spend', 'p75_spend', 'p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad', 'max_pad']
# ['p25_pad', 'p50_pad', 'p75_pad', 'p90_pad', 'p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc', 'p25_pc']
# ['p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 'total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd', 'p50_pd']
# ['p75_pd', 'p90_pd', 'p95_pd', 'total_pp', 'avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp', 'p75_pp']
# ['p90_pp', 'p95_pp', 'mode_product_id', 'last_customer_id', 'last_order_date', 'last_purchase_count', 'last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity']
# ['last_p75_quantity', 'last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend', 'last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend']
# ['last_p90_spend', 'last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad', 'last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad']
# ['last_p95_pad', 'last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc', 'last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc']
# ['last_total_pd', 'last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd', 'last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp']
# ['last_avg_pp', 'last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp', 'last_mode_product_id']

# %%
cpd.head()
# Out:
#    customer_id order_date  purchase_count  avg_quantity  max_quantity  \
# 0        24271 2026-01-04               1           7.0             7
# 1        24271 2026-01-07               1           7.0             7
# 2        24271 2026-01-09               2           7.0             7
# 3        24271 2026-01-10               2           7.0             7
# 4        24271 2026-01-12               1           7.0             7
#
#    p25_quantity  p50_quantity  p75_quantity  p90_quantity  p95_quantity  ...  \
# 0           7.0           7.0           7.0           7.0           7.0  ...
# 1           7.0           7.0           7.0           7.0           7.0  ...
# 2           7.0           7.0           7.0           7.0           7.0  ...
# 3           7.0           7.0           7.0           7.0           7.0  ...
# 4           7.0           7.0           7.0           7.0           7.0  ...
#
#    last_total_pp  last_avg_pp  last_min_pp  last_max_pp  last_p25_pp  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1        56.0919     56.09190      56.0919      56.0919    56.091900
# 2        69.2574     69.25740      69.2574      69.2574    69.257400
# 3        25.6611     12.83055       3.7805      21.8806     8.305525
# 4        92.7520     46.37600       6.6182      86.1338    26.497100
#
#    last_p50_pp  last_p75_pp  last_p90_pp  last_p95_pp  last_mode_product_id
# 0          NaN          NaN          NaN          NaN                   NaN
# 1     56.09190    56.091900     56.09190    56.091900                 439.0
# 2     69.25740    69.257400     69.25740    69.257400                  36.0
# 3     12.83055    17.355575     20.07059    20.975595                  67.0
# 4     46.37600    66.254900     78.18224    82.158020                  55.0
#
# [5 rows x 112 columns]

# %%
cpd.columns
# Out:
# Index(['customer_id', 'order_date', 'purchase_count', 'avg_quantity',
#        'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity',
#        'p90_quantity', 'p95_quantity',
#        ...
#        'last_total_pp', 'last_avg_pp', 'last_min_pp', 'last_max_pp',
#        'last_p25_pp', 'last_p50_pp', 'last_p75_pp', 'last_p90_pp',
#        'last_p95_pp', 'last_mode_product_id'],
#       dtype='object', length=112)

# %%
cpd["Same_order"] = (cpd["mode_product_id"] == cpd["last_mode_product_id"]).astype(int)
cpd["Last_transaction_days"] = (cpd["order_date"] - cpd["last_order_date"] ).dt.days
cpd.drop(['last_customer_id','last_mode_product_id'],axis=1 , inplace = True)

# %%
cpd.columns
# Out:
# Index(['customer_id', 'order_date', 'purchase_count', 'avg_quantity',
#        'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity',
#        'p90_quantity', 'p95_quantity',
#        ...
#        'last_avg_pp', 'last_min_pp', 'last_max_pp', 'last_p25_pp',
#        'last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp',
#        'Same_order', 'Last_transaction_days'],
#       dtype='object', length=112)

# %%
new_cols = [    'purchase_count', 'avg_quantity', 'max_quantity',
                #'p25_quantity','p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity',
                'total_spend', 'avg_spend', 'min_spend', 'max_spend',
                #'p25_spend','p50_spend', 'p75_spend', 'p90_spend', 'p95_spend',
                'total_pad','avg_pad', 'min_pad', 'max_pad', 
                #'p25_pad', 'p50_pad', 'p75_pad','p90_pad', 'p95_pad',
                'total_pc', 'avg_pc', 'min_pc', 'max_pc',
                #'p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 
                'total_pd', 'avg_pd','min_pd', 'max_pd', 
                #'p25_pd', 'p50_pd', 'p75_pd', 'p90_pd', 'p95_pd',
                'total_pp', 'avg_pp', 'min_pp', 'max_pp',
                #'p25_pp', 'p50_pp', 'p75_pp','p90_pp', 'p95_pp' 
           ]

# %%
for i in new_cols : 
    windows = [2, 3, 7, 30]
    group_cols = ["customer_id"]
    # Variables for which you want historical rolling features
    rolling_cols = [ i ]
    
    cpd = cpd.sort_values( group_cols + ["order_date"] ).reset_index(drop=True)
    cpd["order_date"] = pd.to_datetime(cpd["order_date"])
    for col in rolling_cols:
        print(f"\nProcessing: {col}")
        temp = cpd[ group_cols + ["order_date", col] ].copy()
        temp[col] = ( temp.groupby(group_cols)[col].shift(1) )
        temp = temp.set_index("order_date")
        rolling = (temp.groupby(group_cols)[col].rolling("2D", closed="both"))
    
        for days in windows:
            rolling = (temp.groupby(group_cols)[col].rolling( f"{days}D", closed="both", min_periods=1))
            cpd[f"{col}_{days}d_mean"] = ( rolling.mean() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_min"]  = ( rolling.min() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_max"]  = ( rolling.max() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_std"]  = ( rolling.std() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_var"]  = ( rolling.var() .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p25"]  = ( rolling.quantile(0.25) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p50"]  = ( rolling.quantile(0.50) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p75"]  = ( rolling.quantile(0.75) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p90"]  = ( rolling.quantile(0.90) .reset_index(level=group_cols, drop=True) .to_numpy())
            cpd[f"{col}_{days}d_p95"]  = ( rolling.quantile(0.95) .reset_index(level=group_cols, drop=True) .to_numpy())
    
    cpd = cpd.sort_values( group_cols + ["order_date"] ).reset_index(drop=True)
    
    rolling_features = [
        c for c in cpd.columns
        if any( f"_{d}d_" in c for d in windows ) ]
    
    print("\nNumber of rolling features:", len(rolling_features))
    
#print("\nRolling features:")
#print(rolling_features)
# Out:
# Processing: purchase_count
#
# Number of rolling features: 40
#
# Processing: avg_quantity
#
# Number of rolling features: 80
#
# Processing: max_quantity
#
# Number of rolling features: 120
#
# Processing: total_spend
#
# Number of rolling features: 160
#
# Processing: avg_spend
#
# Number of rolling features: 200
#
# Processing: min_spend
#
# Number of rolling features: 240
#
# Processing: max_spend
#
# Number of rolling features: 280
#
# Processing: total_pad
#
# Number of rolling features: 320
#
# Processing: avg_pad
#
# Number of rolling features: 360
#
# Processing: min_pad
#
# Number of rolling features: 400
#
# Processing: max_pad
#
# Number of rolling features: 440
#
# Processing: total_pc
#
# Number of rolling features: 480
#
# Processing: avg_pc
#
# Number of rolling features: 520
#
# Processing: min_pc
#
# Number of rolling features: 560
#
# Processing: max_pc
#
# Number of rolling features: 600
#
# Processing: total_pd
#
# Number of rolling features: 640
#
# Processing: avg_pd
#
# Number of rolling features: 680
#
# Processing: min_pd
#
# Number of rolling features: 720
#
# Processing: max_pd
#
# Number of rolling features: 760
#
# Processing: total_pp
#
# Number of rolling features: 800
#
# Processing: avg_pp
#
# Number of rolling features: 840
#
# Processing: min_pp
#
# Number of rolling features: 880
#
# Processing: max_pp
#
# Number of rolling features: 920

# %%
columns = cpd.columns[3:]

print("=" * 100)
print(f"Total columns: {(cpd.shape)}")
print("=" * 100)
for i in range(0, len(columns), 10):
    print(columns[i:i+10].tolist())
# Out:
# ====================================================================================================
# Total columns: (27, 1032)
# ====================================================================================================
# ['avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity', 'total_spend', 'avg_spend', 'min_spend']
# ['max_spend', 'p25_spend', 'p50_spend', 'p75_spend', 'p90_spend', 'p95_spend', 'total_pad', 'avg_pad', 'min_pad', 'max_pad']
# ['p25_pad', 'p50_pad', 'p75_pad', 'p90_pad', 'p95_pad', 'total_pc', 'avg_pc', 'min_pc', 'max_pc', 'p25_pc']
# ['p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 'total_pd', 'avg_pd', 'min_pd', 'max_pd', 'p25_pd', 'p50_pd']
# ['p75_pd', 'p90_pd', 'p95_pd', 'total_pp', 'avg_pp', 'min_pp', 'max_pp', 'p25_pp', 'p50_pp', 'p75_pp']
# ['p90_pp', 'p95_pp', 'mode_product_id', 'last_order_date', 'last_purchase_count', 'last_avg_quantity', 'last_max_quantity', 'last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity']
# ['last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend', 'last_max_spend', 'last_p25_spend', 'last_p50_spend', 'last_p75_spend', 'last_p90_spend']
# ['last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad', 'last_p25_pad', 'last_p50_pad', 'last_p75_pad', 'last_p90_pad', 'last_p95_pad']
# ['last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc', 'last_p50_pc', 'last_p75_pc', 'last_p90_pc', 'last_p95_pc', 'last_total_pd']
# ['last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd', 'last_p75_pd', 'last_p90_pd', 'last_p95_pd', 'last_total_pp', 'last_avg_pp']
# ['last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp', 'Same_order', 'Last_transaction_days', 'purchase_count_2d_mean']
# ['purchase_count_2d_min', 'purchase_count_2d_max', 'purchase_count_2d_std', 'purchase_count_2d_var', 'purchase_count_2d_p25', 'purchase_count_2d_p50', 'purchase_count_2d_p75', 'purchase_count_2d_p90', 'purchase_count_2d_p95', 'purchase_count_3d_mean']
# ['purchase_count_3d_min', 'purchase_count_3d_max', 'purchase_count_3d_std', 'purchase_count_3d_var', 'purchase_count_3d_p25', 'purchase_count_3d_p50', 'purchase_count_3d_p75', 'purchase_count_3d_p90', 'purchase_count_3d_p95', 'purchase_count_7d_mean']
# ['purchase_count_7d_min', 'purchase_count_7d_max', 'purchase_count_7d_std', 'purchase_count_7d_var', 'purchase_count_7d_p25', 'purchase_count_7d_p50', 'purchase_count_7d_p75', 'purchase_count_7d_p90', 'purchase_count_7d_p95', 'purchase_count_30d_mean']
# ['purchase_count_30d_min', 'purchase_count_30d_max', 'purchase_count_30d_std', 'purchase_count_30d_var', 'purchase_count_30d_p25', 'purchase_count_30d_p50', 'purchase_count_30d_p75', 'purchase_count_30d_p90', 'purchase_count_30d_p95', 'avg_quantity_2d_mean']
# ['avg_quantity_2d_min', 'avg_quantity_2d_max', 'avg_quantity_2d_std', 'avg_quantity_2d_var', 'avg_quantity_2d_p25', 'avg_quantity_2d_p50', 'avg_quantity_2d_p75', 'avg_quantity_2d_p90', 'avg_quantity_2d_p95', 'avg_quantity_3d_mean']
# ['avg_quantity_3d_min', 'avg_quantity_3d_max', 'avg_quantity_3d_std', 'avg_quantity_3d_var', 'avg_quantity_3d_p25', 'avg_quantity_3d_p50', 'avg_quantity_3d_p75', 'avg_quantity_3d_p90', 'avg_quantity_3d_p95', 'avg_quantity_7d_mean']
# ['avg_quantity_7d_min', 'avg_quantity_7d_max', 'avg_quantity_7d_std', 'avg_quantity_7d_var', 'avg_quantity_7d_p25', 'avg_quantity_7d_p50', 'avg_quantity_7d_p75', 'avg_quantity_7d_p90', 'avg_quantity_7d_p95', 'avg_quantity_30d_mean']
# ['avg_quantity_30d_min', 'avg_quantity_30d_max', 'avg_quantity_30d_std', 'avg_quantity_30d_var', 'avg_quantity_30d_p25', 'avg_quantity_30d_p50', 'avg_quantity_30d_p75', 'avg_quantity_30d_p90', 'avg_quantity_30d_p95', 'max_quantity_2d_mean']
# ['max_quantity_2d_min', 'max_quantity_2d_max', 'max_quantity_2d_std', 'max_quantity_2d_var', 'max_quantity_2d_p25', 'max_quantity_2d_p50', 'max_quantity_2d_p75', 'max_quantity_2d_p90', 'max_quantity_2d_p95', 'max_quantity_3d_mean']
# ['max_quantity_3d_min', 'max_quantity_3d_max', 'max_quantity_3d_std', 'max_quantity_3d_var', 'max_quantity_3d_p25', 'max_quantity_3d_p50', 'max_quantity_3d_p75', 'max_quantity_3d_p90', 'max_quantity_3d_p95', 'max_quantity_7d_mean']
# ['max_quantity_7d_min', 'max_quantity_7d_max', 'max_quantity_7d_std', 'max_quantity_7d_var', 'max_quantity_7d_p25', 'max_quantity_7d_p50', 'max_quantity_7d_p75', 'max_quantity_7d_p90', 'max_quantity_7d_p95', 'max_quantity_30d_mean']
# ['max_quantity_30d_min', 'max_quantity_30d_max', 'max_quantity_30d_std', 'max_quantity_30d_var', 'max_quantity_30d_p25', 'max_quantity_30d_p50', 'max_quantity_30d_p75', 'max_quantity_30d_p90', 'max_quantity_30d_p95', 'total_spend_2d_mean']
# ['total_spend_2d_min', 'total_spend_2d_max', 'total_spend_2d_std', 'total_spend_2d_var', 'total_spend_2d_p25', 'total_spend_2d_p50', 'total_spend_2d_p75', 'total_spend_2d_p90', 'total_spend_2d_p95', 'total_spend_3d_mean']
# ['total_spend_3d_min', 'total_spend_3d_max', 'total_spend_3d_std', 'total_spend_3d_var', 'total_spend_3d_p25', 'total_spend_3d_p50', 'total_spend_3d_p75', 'total_spend_3d_p90', 'total_spend_3d_p95', 'total_spend_7d_mean']
# ['total_spend_7d_min', 'total_spend_7d_max', 'total_spend_7d_std', 'total_spend_7d_var', 'total_spend_7d_p25', 'total_spend_7d_p50', 'total_spend_7d_p75', 'total_spend_7d_p90', 'total_spend_7d_p95', 'total_spend_30d_mean']
# ['total_spend_30d_min', 'total_spend_30d_max', 'total_spend_30d_std', 'total_spend_30d_var', 'total_spend_30d_p25', 'total_spend_30d_p50', 'total_spend_30d_p75', 'total_spend_30d_p90', 'total_spend_30d_p95', 'avg_spend_2d_mean']
# ['avg_spend_2d_min', 'avg_spend_2d_max', 'avg_spend_2d_std', 'avg_spend_2d_var', 'avg_spend_2d_p25', 'avg_spend_2d_p50', 'avg_spend_2d_p75', 'avg_spend_2d_p90', 'avg_spend_2d_p95', 'avg_spend_3d_mean']
# ['avg_spend_3d_min', 'avg_spend_3d_max', 'avg_spend_3d_std', 'avg_spend_3d_var', 'avg_spend_3d_p25', 'avg_spend_3d_p50', 'avg_spend_3d_p75', 'avg_spend_3d_p90', 'avg_spend_3d_p95', 'avg_spend_7d_mean']
# ['avg_spend_7d_min', 'avg_spend_7d_max', 'avg_spend_7d_std', 'avg_spend_7d_var', 'avg_spend_7d_p25', 'avg_spend_7d_p50', 'avg_spend_7d_p75', 'avg_spend_7d_p90', 'avg_spend_7d_p95', 'avg_spend_30d_mean']
# ['avg_spend_30d_min', 'avg_spend_30d_max', 'avg_spend_30d_std', 'avg_spend_30d_var', 'avg_spend_30d_p25', 'avg_spend_30d_p50', 'avg_spend_30d_p75', 'avg_spend_30d_p90', 'avg_spend_30d_p95', 'min_spend_2d_mean']
# ['min_spend_2d_min', 'min_spend_2d_max', 'min_spend_2d_std', 'min_spend_2d_var', 'min_spend_2d_p25', 'min_spend_2d_p50', 'min_spend_2d_p75', 'min_spend_2d_p90', 'min_spend_2d_p95', 'min_spend_3d_mean']
# ['min_spend_3d_min', 'min_spend_3d_max', 'min_spend_3d_std', 'min_spend_3d_var', 'min_spend_3d_p25', 'min_spend_3d_p50', 'min_spend_3d_p75', 'min_spend_3d_p90', 'min_spend_3d_p95', 'min_spend_7d_mean']
# ['min_spend_7d_min', 'min_spend_7d_max', 'min_spend_7d_std', 'min_spend_7d_var', 'min_spend_7d_p25', 'min_spend_7d_p50', 'min_spend_7d_p75', 'min_spend_7d_p90', 'min_spend_7d_p95', 'min_spend_30d_mean']
# ['min_spend_30d_min', 'min_spend_30d_max', 'min_spend_30d_std', 'min_spend_30d_var', 'min_spend_30d_p25', 'min_spend_30d_p50', 'min_spend_30d_p75', 'min_spend_30d_p90', 'min_spend_30d_p95', 'max_spend_2d_mean']
# ['max_spend_2d_min', 'max_spend_2d_max', 'max_spend_2d_std', 'max_spend_2d_var', 'max_spend_2d_p25', 'max_spend_2d_p50', 'max_spend_2d_p75', 'max_spend_2d_p90', 'max_spend_2d_p95', 'max_spend_3d_mean']
# ['max_spend_3d_min', 'max_spend_3d_max', 'max_spend_3d_std', 'max_spend_3d_var', 'max_spend_3d_p25', 'max_spend_3d_p50', 'max_spend_3d_p75', 'max_spend_3d_p90', 'max_spend_3d_p95', 'max_spend_7d_mean']
# ['max_spend_7d_min', 'max_spend_7d_max', 'max_spend_7d_std', 'max_spend_7d_var', 'max_spend_7d_p25', 'max_spend_7d_p50', 'max_spend_7d_p75', 'max_spend_7d_p90', 'max_spend_7d_p95', 'max_spend_30d_mean']
# ['max_spend_30d_min', 'max_spend_30d_max', 'max_spend_30d_std', 'max_spend_30d_var', 'max_spend_30d_p25', 'max_spend_30d_p50', 'max_spend_30d_p75', 'max_spend_30d_p90', 'max_spend_30d_p95', 'total_pad_2d_mean']
# ['total_pad_2d_min', 'total_pad_2d_max', 'total_pad_2d_std', 'total_pad_2d_var', 'total_pad_2d_p25', 'total_pad_2d_p50', 'total_pad_2d_p75', 'total_pad_2d_p90', 'total_pad_2d_p95', 'total_pad_3d_mean']
# ['total_pad_3d_min', 'total_pad_3d_max', 'total_pad_3d_std', 'total_pad_3d_var', 'total_pad_3d_p25', 'total_pad_3d_p50', 'total_pad_3d_p75', 'total_pad_3d_p90', 'total_pad_3d_p95', 'total_pad_7d_mean']
# ['total_pad_7d_min', 'total_pad_7d_max', 'total_pad_7d_std', 'total_pad_7d_var', 'total_pad_7d_p25', 'total_pad_7d_p50', 'total_pad_7d_p75', 'total_pad_7d_p90', 'total_pad_7d_p95', 'total_pad_30d_mean']
# ['total_pad_30d_min', 'total_pad_30d_max', 'total_pad_30d_std', 'total_pad_30d_var', 'total_pad_30d_p25', 'total_pad_30d_p50', 'total_pad_30d_p75', 'total_pad_30d_p90', 'total_pad_30d_p95', 'avg_pad_2d_mean']
# ['avg_pad_2d_min', 'avg_pad_2d_max', 'avg_pad_2d_std', 'avg_pad_2d_var', 'avg_pad_2d_p25', 'avg_pad_2d_p50', 'avg_pad_2d_p75', 'avg_pad_2d_p90', 'avg_pad_2d_p95', 'avg_pad_3d_mean']
# ['avg_pad_3d_min', 'avg_pad_3d_max', 'avg_pad_3d_std', 'avg_pad_3d_var', 'avg_pad_3d_p25', 'avg_pad_3d_p50', 'avg_pad_3d_p75', 'avg_pad_3d_p90', 'avg_pad_3d_p95', 'avg_pad_7d_mean']
# ['avg_pad_7d_min', 'avg_pad_7d_max', 'avg_pad_7d_std', 'avg_pad_7d_var', 'avg_pad_7d_p25', 'avg_pad_7d_p50', 'avg_pad_7d_p75', 'avg_pad_7d_p90', 'avg_pad_7d_p95', 'avg_pad_30d_mean']
# ['avg_pad_30d_min', 'avg_pad_30d_max', 'avg_pad_30d_std', 'avg_pad_30d_var', 'avg_pad_30d_p25', 'avg_pad_30d_p50', 'avg_pad_30d_p75', 'avg_pad_30d_p90', 'avg_pad_30d_p95', 'min_pad_2d_mean']
# ['min_pad_2d_min', 'min_pad_2d_max', 'min_pad_2d_std', 'min_pad_2d_var', 'min_pad_2d_p25', 'min_pad_2d_p50', 'min_pad_2d_p75', 'min_pad_2d_p90', 'min_pad_2d_p95', 'min_pad_3d_mean']
# ['min_pad_3d_min', 'min_pad_3d_max', 'min_pad_3d_std', 'min_pad_3d_var', 'min_pad_3d_p25', 'min_pad_3d_p50', 'min_pad_3d_p75', 'min_pad_3d_p90', 'min_pad_3d_p95', 'min_pad_7d_mean']
# ['min_pad_7d_min', 'min_pad_7d_max', 'min_pad_7d_std', 'min_pad_7d_var', 'min_pad_7d_p25', 'min_pad_7d_p50', 'min_pad_7d_p75', 'min_pad_7d_p90', 'min_pad_7d_p95', 'min_pad_30d_mean']
# ['min_pad_30d_min', 'min_pad_30d_max', 'min_pad_30d_std', 'min_pad_30d_var', 'min_pad_30d_p25', 'min_pad_30d_p50', 'min_pad_30d_p75', 'min_pad_30d_p90', 'min_pad_30d_p95', 'max_pad_2d_mean']
# ['max_pad_2d_min', 'max_pad_2d_max', 'max_pad_2d_std', 'max_pad_2d_var', 'max_pad_2d_p25', 'max_pad_2d_p50', 'max_pad_2d_p75', 'max_pad_2d_p90', 'max_pad_2d_p95', 'max_pad_3d_mean']
# ['max_pad_3d_min', 'max_pad_3d_max', 'max_pad_3d_std', 'max_pad_3d_var', 'max_pad_3d_p25', 'max_pad_3d_p50', 'max_pad_3d_p75', 'max_pad_3d_p90', 'max_pad_3d_p95', 'max_pad_7d_mean']
# ['max_pad_7d_min', 'max_pad_7d_max', 'max_pad_7d_std', 'max_pad_7d_var', 'max_pad_7d_p25', 'max_pad_7d_p50', 'max_pad_7d_p75', 'max_pad_7d_p90', 'max_pad_7d_p95', 'max_pad_30d_mean']
# ['max_pad_30d_min', 'max_pad_30d_max', 'max_pad_30d_std', 'max_pad_30d_var', 'max_pad_30d_p25', 'max_pad_30d_p50', 'max_pad_30d_p75', 'max_pad_30d_p90', 'max_pad_30d_p95', 'total_pc_2d_mean']
# ['total_pc_2d_min', 'total_pc_2d_max', 'total_pc_2d_std', 'total_pc_2d_var', 'total_pc_2d_p25', 'total_pc_2d_p50', 'total_pc_2d_p75', 'total_pc_2d_p90', 'total_pc_2d_p95', 'total_pc_3d_mean']
# ['total_pc_3d_min', 'total_pc_3d_max', 'total_pc_3d_std', 'total_pc_3d_var', 'total_pc_3d_p25', 'total_pc_3d_p50', 'total_pc_3d_p75', 'total_pc_3d_p90', 'total_pc_3d_p95', 'total_pc_7d_mean']
# ['total_pc_7d_min', 'total_pc_7d_max', 'total_pc_7d_std', 'total_pc_7d_var', 'total_pc_7d_p25', 'total_pc_7d_p50', 'total_pc_7d_p75', 'total_pc_7d_p90', 'total_pc_7d_p95', 'total_pc_30d_mean']
# ['total_pc_30d_min', 'total_pc_30d_max', 'total_pc_30d_std', 'total_pc_30d_var', 'total_pc_30d_p25', 'total_pc_30d_p50', 'total_pc_30d_p75', 'total_pc_30d_p90', 'total_pc_30d_p95', 'avg_pc_2d_mean']
# ['avg_pc_2d_min', 'avg_pc_2d_max', 'avg_pc_2d_std', 'avg_pc_2d_var', 'avg_pc_2d_p25', 'avg_pc_2d_p50', 'avg_pc_2d_p75', 'avg_pc_2d_p90', 'avg_pc_2d_p95', 'avg_pc_3d_mean']
# ['avg_pc_3d_min', 'avg_pc_3d_max', 'avg_pc_3d_std', 'avg_pc_3d_var', 'avg_pc_3d_p25', 'avg_pc_3d_p50', 'avg_pc_3d_p75', 'avg_pc_3d_p90', 'avg_pc_3d_p95', 'avg_pc_7d_mean']
# ['avg_pc_7d_min', 'avg_pc_7d_max', 'avg_pc_7d_std', 'avg_pc_7d_var', 'avg_pc_7d_p25', 'avg_pc_7d_p50', 'avg_pc_7d_p75', 'avg_pc_7d_p90', 'avg_pc_7d_p95', 'avg_pc_30d_mean']
# ['avg_pc_30d_min', 'avg_pc_30d_max', 'avg_pc_30d_std', 'avg_pc_30d_var', 'avg_pc_30d_p25', 'avg_pc_30d_p50', 'avg_pc_30d_p75', 'avg_pc_30d_p90', 'avg_pc_30d_p95', 'min_pc_2d_mean']
# ['min_pc_2d_min', 'min_pc_2d_max', 'min_pc_2d_std', 'min_pc_2d_var', 'min_pc_2d_p25', 'min_pc_2d_p50', 'min_pc_2d_p75', 'min_pc_2d_p90', 'min_pc_2d_p95', 'min_pc_3d_mean']
# ['min_pc_3d_min', 'min_pc_3d_max', 'min_pc_3d_std', 'min_pc_3d_var', 'min_pc_3d_p25', 'min_pc_3d_p50', 'min_pc_3d_p75', 'min_pc_3d_p90', 'min_pc_3d_p95', 'min_pc_7d_mean']
# ['min_pc_7d_min', 'min_pc_7d_max', 'min_pc_7d_std', 'min_pc_7d_var', 'min_pc_7d_p25', 'min_pc_7d_p50', 'min_pc_7d_p75', 'min_pc_7d_p90', 'min_pc_7d_p95', 'min_pc_30d_mean']
# ['min_pc_30d_min', 'min_pc_30d_max', 'min_pc_30d_std', 'min_pc_30d_var', 'min_pc_30d_p25', 'min_pc_30d_p50', 'min_pc_30d_p75', 'min_pc_30d_p90', 'min_pc_30d_p95', 'max_pc_2d_mean']
# ['max_pc_2d_min', 'max_pc_2d_max', 'max_pc_2d_std', 'max_pc_2d_var', 'max_pc_2d_p25', 'max_pc_2d_p50', 'max_pc_2d_p75', 'max_pc_2d_p90', 'max_pc_2d_p95', 'max_pc_3d_mean']
# ['max_pc_3d_min', 'max_pc_3d_max', 'max_pc_3d_std', 'max_pc_3d_var', 'max_pc_3d_p25', 'max_pc_3d_p50', 'max_pc_3d_p75', 'max_pc_3d_p90', 'max_pc_3d_p95', 'max_pc_7d_mean']
# ['max_pc_7d_min', 'max_pc_7d_max', 'max_pc_7d_std', 'max_pc_7d_var', 'max_pc_7d_p25', 'max_pc_7d_p50', 'max_pc_7d_p75', 'max_pc_7d_p90', 'max_pc_7d_p95', 'max_pc_30d_mean']
# ['max_pc_30d_min', 'max_pc_30d_max', 'max_pc_30d_std', 'max_pc_30d_var', 'max_pc_30d_p25', 'max_pc_30d_p50', 'max_pc_30d_p75', 'max_pc_30d_p90', 'max_pc_30d_p95', 'total_pd_2d_mean']
# ['total_pd_2d_min', 'total_pd_2d_max', 'total_pd_2d_std', 'total_pd_2d_var', 'total_pd_2d_p25', 'total_pd_2d_p50', 'total_pd_2d_p75', 'total_pd_2d_p90', 'total_pd_2d_p95', 'total_pd_3d_mean']
# ['total_pd_3d_min', 'total_pd_3d_max', 'total_pd_3d_std', 'total_pd_3d_var', 'total_pd_3d_p25', 'total_pd_3d_p50', 'total_pd_3d_p75', 'total_pd_3d_p90', 'total_pd_3d_p95', 'total_pd_7d_mean']
# ['total_pd_7d_min', 'total_pd_7d_max', 'total_pd_7d_std', 'total_pd_7d_var', 'total_pd_7d_p25', 'total_pd_7d_p50', 'total_pd_7d_p75', 'total_pd_7d_p90', 'total_pd_7d_p95', 'total_pd_30d_mean']
# ['total_pd_30d_min', 'total_pd_30d_max', 'total_pd_30d_std', 'total_pd_30d_var', 'total_pd_30d_p25', 'total_pd_30d_p50', 'total_pd_30d_p75', 'total_pd_30d_p90', 'total_pd_30d_p95', 'avg_pd_2d_mean']
# ['avg_pd_2d_min', 'avg_pd_2d_max', 'avg_pd_2d_std', 'avg_pd_2d_var', 'avg_pd_2d_p25', 'avg_pd_2d_p50', 'avg_pd_2d_p75', 'avg_pd_2d_p90', 'avg_pd_2d_p95', 'avg_pd_3d_mean']
# ['avg_pd_3d_min', 'avg_pd_3d_max', 'avg_pd_3d_std', 'avg_pd_3d_var', 'avg_pd_3d_p25', 'avg_pd_3d_p50', 'avg_pd_3d_p75', 'avg_pd_3d_p90', 'avg_pd_3d_p95', 'avg_pd_7d_mean']
# ['avg_pd_7d_min', 'avg_pd_7d_max', 'avg_pd_7d_std', 'avg_pd_7d_var', 'avg_pd_7d_p25', 'avg_pd_7d_p50', 'avg_pd_7d_p75', 'avg_pd_7d_p90', 'avg_pd_7d_p95', 'avg_pd_30d_mean']
# ['avg_pd_30d_min', 'avg_pd_30d_max', 'avg_pd_30d_std', 'avg_pd_30d_var', 'avg_pd_30d_p25', 'avg_pd_30d_p50', 'avg_pd_30d_p75', 'avg_pd_30d_p90', 'avg_pd_30d_p95', 'min_pd_2d_mean']
# ['min_pd_2d_min', 'min_pd_2d_max', 'min_pd_2d_std', 'min_pd_2d_var', 'min_pd_2d_p25', 'min_pd_2d_p50', 'min_pd_2d_p75', 'min_pd_2d_p90', 'min_pd_2d_p95', 'min_pd_3d_mean']
# ['min_pd_3d_min', 'min_pd_3d_max', 'min_pd_3d_std', 'min_pd_3d_var', 'min_pd_3d_p25', 'min_pd_3d_p50', 'min_pd_3d_p75', 'min_pd_3d_p90', 'min_pd_3d_p95', 'min_pd_7d_mean']
# ['min_pd_7d_min', 'min_pd_7d_max', 'min_pd_7d_std', 'min_pd_7d_var', 'min_pd_7d_p25', 'min_pd_7d_p50', 'min_pd_7d_p75', 'min_pd_7d_p90', 'min_pd_7d_p95', 'min_pd_30d_mean']
# ['min_pd_30d_min', 'min_pd_30d_max', 'min_pd_30d_std', 'min_pd_30d_var', 'min_pd_30d_p25', 'min_pd_30d_p50', 'min_pd_30d_p75', 'min_pd_30d_p90', 'min_pd_30d_p95', 'max_pd_2d_mean']
# ['max_pd_2d_min', 'max_pd_2d_max', 'max_pd_2d_std', 'max_pd_2d_var', 'max_pd_2d_p25', 'max_pd_2d_p50', 'max_pd_2d_p75', 'max_pd_2d_p90', 'max_pd_2d_p95', 'max_pd_3d_mean']
# ['max_pd_3d_min', 'max_pd_3d_max', 'max_pd_3d_std', 'max_pd_3d_var', 'max_pd_3d_p25', 'max_pd_3d_p50', 'max_pd_3d_p75', 'max_pd_3d_p90', 'max_pd_3d_p95', 'max_pd_7d_mean']
# ['max_pd_7d_min', 'max_pd_7d_max', 'max_pd_7d_std', 'max_pd_7d_var', 'max_pd_7d_p25', 'max_pd_7d_p50', 'max_pd_7d_p75', 'max_pd_7d_p90', 'max_pd_7d_p95', 'max_pd_30d_mean']
# ['max_pd_30d_min', 'max_pd_30d_max', 'max_pd_30d_std', 'max_pd_30d_var', 'max_pd_30d_p25', 'max_pd_30d_p50', 'max_pd_30d_p75', 'max_pd_30d_p90', 'max_pd_30d_p95', 'total_pp_2d_mean']
# ['total_pp_2d_min', 'total_pp_2d_max', 'total_pp_2d_std', 'total_pp_2d_var', 'total_pp_2d_p25', 'total_pp_2d_p50', 'total_pp_2d_p75', 'total_pp_2d_p90', 'total_pp_2d_p95', 'total_pp_3d_mean']
# ['total_pp_3d_min', 'total_pp_3d_max', 'total_pp_3d_std', 'total_pp_3d_var', 'total_pp_3d_p25', 'total_pp_3d_p50', 'total_pp_3d_p75', 'total_pp_3d_p90', 'total_pp_3d_p95', 'total_pp_7d_mean']
# ['total_pp_7d_min', 'total_pp_7d_max', 'total_pp_7d_std', 'total_pp_7d_var', 'total_pp_7d_p25', 'total_pp_7d_p50', 'total_pp_7d_p75', 'total_pp_7d_p90', 'total_pp_7d_p95', 'total_pp_30d_mean']
# ['total_pp_30d_min', 'total_pp_30d_max', 'total_pp_30d_std', 'total_pp_30d_var', 'total_pp_30d_p25', 'total_pp_30d_p50', 'total_pp_30d_p75', 'total_pp_30d_p90', 'total_pp_30d_p95', 'avg_pp_2d_mean']
# ['avg_pp_2d_min', 'avg_pp_2d_max', 'avg_pp_2d_std', 'avg_pp_2d_var', 'avg_pp_2d_p25', 'avg_pp_2d_p50', 'avg_pp_2d_p75', 'avg_pp_2d_p90', 'avg_pp_2d_p95', 'avg_pp_3d_mean']
# ['avg_pp_3d_min', 'avg_pp_3d_max', 'avg_pp_3d_std', 'avg_pp_3d_var', 'avg_pp_3d_p25', 'avg_pp_3d_p50', 'avg_pp_3d_p75', 'avg_pp_3d_p90', 'avg_pp_3d_p95', 'avg_pp_7d_mean']
# ['avg_pp_7d_min', 'avg_pp_7d_max', 'avg_pp_7d_std', 'avg_pp_7d_var', 'avg_pp_7d_p25', 'avg_pp_7d_p50', 'avg_pp_7d_p75', 'avg_pp_7d_p90', 'avg_pp_7d_p95', 'avg_pp_30d_mean']
# ['avg_pp_30d_min', 'avg_pp_30d_max', 'avg_pp_30d_std', 'avg_pp_30d_var', 'avg_pp_30d_p25', 'avg_pp_30d_p50', 'avg_pp_30d_p75', 'avg_pp_30d_p90', 'avg_pp_30d_p95', 'min_pp_2d_mean']
# ['min_pp_2d_min', 'min_pp_2d_max', 'min_pp_2d_std', 'min_pp_2d_var', 'min_pp_2d_p25', 'min_pp_2d_p50', 'min_pp_2d_p75', 'min_pp_2d_p90', 'min_pp_2d_p95', 'min_pp_3d_mean']
# ['min_pp_3d_min', 'min_pp_3d_max', 'min_pp_3d_std', 'min_pp_3d_var', 'min_pp_3d_p25', 'min_pp_3d_p50', 'min_pp_3d_p75', 'min_pp_3d_p90', 'min_pp_3d_p95', 'min_pp_7d_mean']
# ['min_pp_7d_min', 'min_pp_7d_max', 'min_pp_7d_std', 'min_pp_7d_var', 'min_pp_7d_p25', 'min_pp_7d_p50', 'min_pp_7d_p75', 'min_pp_7d_p90', 'min_pp_7d_p95', 'min_pp_30d_mean']
# ['min_pp_30d_min', 'min_pp_30d_max', 'min_pp_30d_std', 'min_pp_30d_var', 'min_pp_30d_p25', 'min_pp_30d_p50', 'min_pp_30d_p75', 'min_pp_30d_p90', 'min_pp_30d_p95', 'max_pp_2d_mean']
# ['max_pp_2d_min', 'max_pp_2d_max', 'max_pp_2d_std', 'max_pp_2d_var', 'max_pp_2d_p25', 'max_pp_2d_p50', 'max_pp_2d_p75', 'max_pp_2d_p90', 'max_pp_2d_p95', 'max_pp_3d_mean']
# ['max_pp_3d_min', 'max_pp_3d_max', 'max_pp_3d_std', 'max_pp_3d_var', 'max_pp_3d_p25', 'max_pp_3d_p50', 'max_pp_3d_p75', 'max_pp_3d_p90', 'max_pp_3d_p95', 'max_pp_7d_mean']
# ['max_pp_7d_min', 'max_pp_7d_max', 'max_pp_7d_std', 'max_pp_7d_var', 'max_pp_7d_p25', 'max_pp_7d_p50', 'max_pp_7d_p75', 'max_pp_7d_p90', 'max_pp_7d_p95', 'max_pp_30d_mean']
# ['max_pp_30d_min', 'max_pp_30d_max', 'max_pp_30d_std', 'max_pp_30d_var', 'max_pp_30d_p25', 'max_pp_30d_p50', 'max_pp_30d_p75', 'max_pp_30d_p90', 'max_pp_30d_p95']

# %%
cpd.columns
# Out:
# Index(['customer_id', 'order_date', 'purchase_count', 'avg_quantity',
#        'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity',
#        'p90_quantity', 'p95_quantity',
#        ...
#        'max_pp_30d_mean', 'max_pp_30d_min', 'max_pp_30d_max', 'max_pp_30d_std',
#        'max_pp_30d_var', 'max_pp_30d_p25', 'max_pp_30d_p50', 'max_pp_30d_p75',
#        'max_pp_30d_p90', 'max_pp_30d_p95'],
#       dtype='object', length=1032)

# %%
columns = cpd.columns

print("=" * 100)
print(f"Total columns: {(cpd.shape)}")
print("=" * 10)
for i in range(0, len(columns), 10):
    print(columns[i:i+10].tolist())
# Out:
# ====================================================================================================
# Total columns: (27, 1032)
# ==========
# ['customer_id', 'order_date', 'purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity']
# ['total_spend', 'avg_spend', 'min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend', 'p90_spend', 'p95_spend', 'total_pad']
# ['avg_pad', 'min_pad', 'max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad', 'p95_pad', 'total_pc', 'avg_pc']
# ['min_pc', 'max_pc', 'p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 'total_pd', 'avg_pd', 'min_pd']
# ['max_pd', 'p25_pd', 'p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp', 'avg_pp', 'min_pp', 'max_pp']
# ['p25_pp', 'p50_pp', 'p75_pp', 'p90_pp', 'p95_pp', 'mode_product_id', 'last_order_date', 'last_purchase_count', 'last_avg_quantity', 'last_max_quantity']
# ['last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity', 'last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend', 'last_max_spend', 'last_p25_spend']
# ['last_p50_spend', 'last_p75_spend', 'last_p90_spend', 'last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad', 'last_p25_pad', 'last_p50_pad']
# ['last_p75_pad', 'last_p90_pad', 'last_p95_pad', 'last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc', 'last_p50_pc', 'last_p75_pc']
# ['last_p90_pc', 'last_p95_pc', 'last_total_pd', 'last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd', 'last_p75_pd', 'last_p90_pd']
# ['last_p95_pd', 'last_total_pp', 'last_avg_pp', 'last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp']
# ['Same_order', 'Last_transaction_days', 'purchase_count_2d_mean', 'purchase_count_2d_min', 'purchase_count_2d_max', 'purchase_count_2d_std', 'purchase_count_2d_var', 'purchase_count_2d_p25', 'purchase_count_2d_p50', 'purchase_count_2d_p75']
# ['purchase_count_2d_p90', 'purchase_count_2d_p95', 'purchase_count_3d_mean', 'purchase_count_3d_min', 'purchase_count_3d_max', 'purchase_count_3d_std', 'purchase_count_3d_var', 'purchase_count_3d_p25', 'purchase_count_3d_p50', 'purchase_count_3d_p75']
# ['purchase_count_3d_p90', 'purchase_count_3d_p95', 'purchase_count_7d_mean', 'purchase_count_7d_min', 'purchase_count_7d_max', 'purchase_count_7d_std', 'purchase_count_7d_var', 'purchase_count_7d_p25', 'purchase_count_7d_p50', 'purchase_count_7d_p75']
# ['purchase_count_7d_p90', 'purchase_count_7d_p95', 'purchase_count_30d_mean', 'purchase_count_30d_min', 'purchase_count_30d_max', 'purchase_count_30d_std', 'purchase_count_30d_var', 'purchase_count_30d_p25', 'purchase_count_30d_p50', 'purchase_count_30d_p75']
# ['purchase_count_30d_p90', 'purchase_count_30d_p95', 'avg_quantity_2d_mean', 'avg_quantity_2d_min', 'avg_quantity_2d_max', 'avg_quantity_2d_std', 'avg_quantity_2d_var', 'avg_quantity_2d_p25', 'avg_quantity_2d_p50', 'avg_quantity_2d_p75']
# ['avg_quantity_2d_p90', 'avg_quantity_2d_p95', 'avg_quantity_3d_mean', 'avg_quantity_3d_min', 'avg_quantity_3d_max', 'avg_quantity_3d_std', 'avg_quantity_3d_var', 'avg_quantity_3d_p25', 'avg_quantity_3d_p50', 'avg_quantity_3d_p75']
# ['avg_quantity_3d_p90', 'avg_quantity_3d_p95', 'avg_quantity_7d_mean', 'avg_quantity_7d_min', 'avg_quantity_7d_max', 'avg_quantity_7d_std', 'avg_quantity_7d_var', 'avg_quantity_7d_p25', 'avg_quantity_7d_p50', 'avg_quantity_7d_p75']
# ['avg_quantity_7d_p90', 'avg_quantity_7d_p95', 'avg_quantity_30d_mean', 'avg_quantity_30d_min', 'avg_quantity_30d_max', 'avg_quantity_30d_std', 'avg_quantity_30d_var', 'avg_quantity_30d_p25', 'avg_quantity_30d_p50', 'avg_quantity_30d_p75']
# ['avg_quantity_30d_p90', 'avg_quantity_30d_p95', 'max_quantity_2d_mean', 'max_quantity_2d_min', 'max_quantity_2d_max', 'max_quantity_2d_std', 'max_quantity_2d_var', 'max_quantity_2d_p25', 'max_quantity_2d_p50', 'max_quantity_2d_p75']
# ['max_quantity_2d_p90', 'max_quantity_2d_p95', 'max_quantity_3d_mean', 'max_quantity_3d_min', 'max_quantity_3d_max', 'max_quantity_3d_std', 'max_quantity_3d_var', 'max_quantity_3d_p25', 'max_quantity_3d_p50', 'max_quantity_3d_p75']
# ['max_quantity_3d_p90', 'max_quantity_3d_p95', 'max_quantity_7d_mean', 'max_quantity_7d_min', 'max_quantity_7d_max', 'max_quantity_7d_std', 'max_quantity_7d_var', 'max_quantity_7d_p25', 'max_quantity_7d_p50', 'max_quantity_7d_p75']
# ['max_quantity_7d_p90', 'max_quantity_7d_p95', 'max_quantity_30d_mean', 'max_quantity_30d_min', 'max_quantity_30d_max', 'max_quantity_30d_std', 'max_quantity_30d_var', 'max_quantity_30d_p25', 'max_quantity_30d_p50', 'max_quantity_30d_p75']
# ['max_quantity_30d_p90', 'max_quantity_30d_p95', 'total_spend_2d_mean', 'total_spend_2d_min', 'total_spend_2d_max', 'total_spend_2d_std', 'total_spend_2d_var', 'total_spend_2d_p25', 'total_spend_2d_p50', 'total_spend_2d_p75']
# ['total_spend_2d_p90', 'total_spend_2d_p95', 'total_spend_3d_mean', 'total_spend_3d_min', 'total_spend_3d_max', 'total_spend_3d_std', 'total_spend_3d_var', 'total_spend_3d_p25', 'total_spend_3d_p50', 'total_spend_3d_p75']
# ['total_spend_3d_p90', 'total_spend_3d_p95', 'total_spend_7d_mean', 'total_spend_7d_min', 'total_spend_7d_max', 'total_spend_7d_std', 'total_spend_7d_var', 'total_spend_7d_p25', 'total_spend_7d_p50', 'total_spend_7d_p75']
# ['total_spend_7d_p90', 'total_spend_7d_p95', 'total_spend_30d_mean', 'total_spend_30d_min', 'total_spend_30d_max', 'total_spend_30d_std', 'total_spend_30d_var', 'total_spend_30d_p25', 'total_spend_30d_p50', 'total_spend_30d_p75']
# ['total_spend_30d_p90', 'total_spend_30d_p95', 'avg_spend_2d_mean', 'avg_spend_2d_min', 'avg_spend_2d_max', 'avg_spend_2d_std', 'avg_spend_2d_var', 'avg_spend_2d_p25', 'avg_spend_2d_p50', 'avg_spend_2d_p75']
# ['avg_spend_2d_p90', 'avg_spend_2d_p95', 'avg_spend_3d_mean', 'avg_spend_3d_min', 'avg_spend_3d_max', 'avg_spend_3d_std', 'avg_spend_3d_var', 'avg_spend_3d_p25', 'avg_spend_3d_p50', 'avg_spend_3d_p75']
# ['avg_spend_3d_p90', 'avg_spend_3d_p95', 'avg_spend_7d_mean', 'avg_spend_7d_min', 'avg_spend_7d_max', 'avg_spend_7d_std', 'avg_spend_7d_var', 'avg_spend_7d_p25', 'avg_spend_7d_p50', 'avg_spend_7d_p75']
# ['avg_spend_7d_p90', 'avg_spend_7d_p95', 'avg_spend_30d_mean', 'avg_spend_30d_min', 'avg_spend_30d_max', 'avg_spend_30d_std', 'avg_spend_30d_var', 'avg_spend_30d_p25', 'avg_spend_30d_p50', 'avg_spend_30d_p75']
# ['avg_spend_30d_p90', 'avg_spend_30d_p95', 'min_spend_2d_mean', 'min_spend_2d_min', 'min_spend_2d_max', 'min_spend_2d_std', 'min_spend_2d_var', 'min_spend_2d_p25', 'min_spend_2d_p50', 'min_spend_2d_p75']
# ['min_spend_2d_p90', 'min_spend_2d_p95', 'min_spend_3d_mean', 'min_spend_3d_min', 'min_spend_3d_max', 'min_spend_3d_std', 'min_spend_3d_var', 'min_spend_3d_p25', 'min_spend_3d_p50', 'min_spend_3d_p75']
# ['min_spend_3d_p90', 'min_spend_3d_p95', 'min_spend_7d_mean', 'min_spend_7d_min', 'min_spend_7d_max', 'min_spend_7d_std', 'min_spend_7d_var', 'min_spend_7d_p25', 'min_spend_7d_p50', 'min_spend_7d_p75']
# ['min_spend_7d_p90', 'min_spend_7d_p95', 'min_spend_30d_mean', 'min_spend_30d_min', 'min_spend_30d_max', 'min_spend_30d_std', 'min_spend_30d_var', 'min_spend_30d_p25', 'min_spend_30d_p50', 'min_spend_30d_p75']
# ['min_spend_30d_p90', 'min_spend_30d_p95', 'max_spend_2d_mean', 'max_spend_2d_min', 'max_spend_2d_max', 'max_spend_2d_std', 'max_spend_2d_var', 'max_spend_2d_p25', 'max_spend_2d_p50', 'max_spend_2d_p75']
# ['max_spend_2d_p90', 'max_spend_2d_p95', 'max_spend_3d_mean', 'max_spend_3d_min', 'max_spend_3d_max', 'max_spend_3d_std', 'max_spend_3d_var', 'max_spend_3d_p25', 'max_spend_3d_p50', 'max_spend_3d_p75']
# ['max_spend_3d_p90', 'max_spend_3d_p95', 'max_spend_7d_mean', 'max_spend_7d_min', 'max_spend_7d_max', 'max_spend_7d_std', 'max_spend_7d_var', 'max_spend_7d_p25', 'max_spend_7d_p50', 'max_spend_7d_p75']
# ['max_spend_7d_p90', 'max_spend_7d_p95', 'max_spend_30d_mean', 'max_spend_30d_min', 'max_spend_30d_max', 'max_spend_30d_std', 'max_spend_30d_var', 'max_spend_30d_p25', 'max_spend_30d_p50', 'max_spend_30d_p75']
# ['max_spend_30d_p90', 'max_spend_30d_p95', 'total_pad_2d_mean', 'total_pad_2d_min', 'total_pad_2d_max', 'total_pad_2d_std', 'total_pad_2d_var', 'total_pad_2d_p25', 'total_pad_2d_p50', 'total_pad_2d_p75']
# ['total_pad_2d_p90', 'total_pad_2d_p95', 'total_pad_3d_mean', 'total_pad_3d_min', 'total_pad_3d_max', 'total_pad_3d_std', 'total_pad_3d_var', 'total_pad_3d_p25', 'total_pad_3d_p50', 'total_pad_3d_p75']
# ['total_pad_3d_p90', 'total_pad_3d_p95', 'total_pad_7d_mean', 'total_pad_7d_min', 'total_pad_7d_max', 'total_pad_7d_std', 'total_pad_7d_var', 'total_pad_7d_p25', 'total_pad_7d_p50', 'total_pad_7d_p75']
# ['total_pad_7d_p90', 'total_pad_7d_p95', 'total_pad_30d_mean', 'total_pad_30d_min', 'total_pad_30d_max', 'total_pad_30d_std', 'total_pad_30d_var', 'total_pad_30d_p25', 'total_pad_30d_p50', 'total_pad_30d_p75']
# ['total_pad_30d_p90', 'total_pad_30d_p95', 'avg_pad_2d_mean', 'avg_pad_2d_min', 'avg_pad_2d_max', 'avg_pad_2d_std', 'avg_pad_2d_var', 'avg_pad_2d_p25', 'avg_pad_2d_p50', 'avg_pad_2d_p75']
# ['avg_pad_2d_p90', 'avg_pad_2d_p95', 'avg_pad_3d_mean', 'avg_pad_3d_min', 'avg_pad_3d_max', 'avg_pad_3d_std', 'avg_pad_3d_var', 'avg_pad_3d_p25', 'avg_pad_3d_p50', 'avg_pad_3d_p75']
# ['avg_pad_3d_p90', 'avg_pad_3d_p95', 'avg_pad_7d_mean', 'avg_pad_7d_min', 'avg_pad_7d_max', 'avg_pad_7d_std', 'avg_pad_7d_var', 'avg_pad_7d_p25', 'avg_pad_7d_p50', 'avg_pad_7d_p75']
# ['avg_pad_7d_p90', 'avg_pad_7d_p95', 'avg_pad_30d_mean', 'avg_pad_30d_min', 'avg_pad_30d_max', 'avg_pad_30d_std', 'avg_pad_30d_var', 'avg_pad_30d_p25', 'avg_pad_30d_p50', 'avg_pad_30d_p75']
# ['avg_pad_30d_p90', 'avg_pad_30d_p95', 'min_pad_2d_mean', 'min_pad_2d_min', 'min_pad_2d_max', 'min_pad_2d_std', 'min_pad_2d_var', 'min_pad_2d_p25', 'min_pad_2d_p50', 'min_pad_2d_p75']
# ['min_pad_2d_p90', 'min_pad_2d_p95', 'min_pad_3d_mean', 'min_pad_3d_min', 'min_pad_3d_max', 'min_pad_3d_std', 'min_pad_3d_var', 'min_pad_3d_p25', 'min_pad_3d_p50', 'min_pad_3d_p75']
# ['min_pad_3d_p90', 'min_pad_3d_p95', 'min_pad_7d_mean', 'min_pad_7d_min', 'min_pad_7d_max', 'min_pad_7d_std', 'min_pad_7d_var', 'min_pad_7d_p25', 'min_pad_7d_p50', 'min_pad_7d_p75']
# ['min_pad_7d_p90', 'min_pad_7d_p95', 'min_pad_30d_mean', 'min_pad_30d_min', 'min_pad_30d_max', 'min_pad_30d_std', 'min_pad_30d_var', 'min_pad_30d_p25', 'min_pad_30d_p50', 'min_pad_30d_p75']
# ['min_pad_30d_p90', 'min_pad_30d_p95', 'max_pad_2d_mean', 'max_pad_2d_min', 'max_pad_2d_max', 'max_pad_2d_std', 'max_pad_2d_var', 'max_pad_2d_p25', 'max_pad_2d_p50', 'max_pad_2d_p75']
# ['max_pad_2d_p90', 'max_pad_2d_p95', 'max_pad_3d_mean', 'max_pad_3d_min', 'max_pad_3d_max', 'max_pad_3d_std', 'max_pad_3d_var', 'max_pad_3d_p25', 'max_pad_3d_p50', 'max_pad_3d_p75']
# ['max_pad_3d_p90', 'max_pad_3d_p95', 'max_pad_7d_mean', 'max_pad_7d_min', 'max_pad_7d_max', 'max_pad_7d_std', 'max_pad_7d_var', 'max_pad_7d_p25', 'max_pad_7d_p50', 'max_pad_7d_p75']
# ['max_pad_7d_p90', 'max_pad_7d_p95', 'max_pad_30d_mean', 'max_pad_30d_min', 'max_pad_30d_max', 'max_pad_30d_std', 'max_pad_30d_var', 'max_pad_30d_p25', 'max_pad_30d_p50', 'max_pad_30d_p75']
# ['max_pad_30d_p90', 'max_pad_30d_p95', 'total_pc_2d_mean', 'total_pc_2d_min', 'total_pc_2d_max', 'total_pc_2d_std', 'total_pc_2d_var', 'total_pc_2d_p25', 'total_pc_2d_p50', 'total_pc_2d_p75']
# ['total_pc_2d_p90', 'total_pc_2d_p95', 'total_pc_3d_mean', 'total_pc_3d_min', 'total_pc_3d_max', 'total_pc_3d_std', 'total_pc_3d_var', 'total_pc_3d_p25', 'total_pc_3d_p50', 'total_pc_3d_p75']
# ['total_pc_3d_p90', 'total_pc_3d_p95', 'total_pc_7d_mean', 'total_pc_7d_min', 'total_pc_7d_max', 'total_pc_7d_std', 'total_pc_7d_var', 'total_pc_7d_p25', 'total_pc_7d_p50', 'total_pc_7d_p75']
# ['total_pc_7d_p90', 'total_pc_7d_p95', 'total_pc_30d_mean', 'total_pc_30d_min', 'total_pc_30d_max', 'total_pc_30d_std', 'total_pc_30d_var', 'total_pc_30d_p25', 'total_pc_30d_p50', 'total_pc_30d_p75']
# ['total_pc_30d_p90', 'total_pc_30d_p95', 'avg_pc_2d_mean', 'avg_pc_2d_min', 'avg_pc_2d_max', 'avg_pc_2d_std', 'avg_pc_2d_var', 'avg_pc_2d_p25', 'avg_pc_2d_p50', 'avg_pc_2d_p75']
# ['avg_pc_2d_p90', 'avg_pc_2d_p95', 'avg_pc_3d_mean', 'avg_pc_3d_min', 'avg_pc_3d_max', 'avg_pc_3d_std', 'avg_pc_3d_var', 'avg_pc_3d_p25', 'avg_pc_3d_p50', 'avg_pc_3d_p75']
# ['avg_pc_3d_p90', 'avg_pc_3d_p95', 'avg_pc_7d_mean', 'avg_pc_7d_min', 'avg_pc_7d_max', 'avg_pc_7d_std', 'avg_pc_7d_var', 'avg_pc_7d_p25', 'avg_pc_7d_p50', 'avg_pc_7d_p75']
# ['avg_pc_7d_p90', 'avg_pc_7d_p95', 'avg_pc_30d_mean', 'avg_pc_30d_min', 'avg_pc_30d_max', 'avg_pc_30d_std', 'avg_pc_30d_var', 'avg_pc_30d_p25', 'avg_pc_30d_p50', 'avg_pc_30d_p75']
# ['avg_pc_30d_p90', 'avg_pc_30d_p95', 'min_pc_2d_mean', 'min_pc_2d_min', 'min_pc_2d_max', 'min_pc_2d_std', 'min_pc_2d_var', 'min_pc_2d_p25', 'min_pc_2d_p50', 'min_pc_2d_p75']
# ['min_pc_2d_p90', 'min_pc_2d_p95', 'min_pc_3d_mean', 'min_pc_3d_min', 'min_pc_3d_max', 'min_pc_3d_std', 'min_pc_3d_var', 'min_pc_3d_p25', 'min_pc_3d_p50', 'min_pc_3d_p75']
# ['min_pc_3d_p90', 'min_pc_3d_p95', 'min_pc_7d_mean', 'min_pc_7d_min', 'min_pc_7d_max', 'min_pc_7d_std', 'min_pc_7d_var', 'min_pc_7d_p25', 'min_pc_7d_p50', 'min_pc_7d_p75']
# ['min_pc_7d_p90', 'min_pc_7d_p95', 'min_pc_30d_mean', 'min_pc_30d_min', 'min_pc_30d_max', 'min_pc_30d_std', 'min_pc_30d_var', 'min_pc_30d_p25', 'min_pc_30d_p50', 'min_pc_30d_p75']
# ['min_pc_30d_p90', 'min_pc_30d_p95', 'max_pc_2d_mean', 'max_pc_2d_min', 'max_pc_2d_max', 'max_pc_2d_std', 'max_pc_2d_var', 'max_pc_2d_p25', 'max_pc_2d_p50', 'max_pc_2d_p75']
# ['max_pc_2d_p90', 'max_pc_2d_p95', 'max_pc_3d_mean', 'max_pc_3d_min', 'max_pc_3d_max', 'max_pc_3d_std', 'max_pc_3d_var', 'max_pc_3d_p25', 'max_pc_3d_p50', 'max_pc_3d_p75']
# ['max_pc_3d_p90', 'max_pc_3d_p95', 'max_pc_7d_mean', 'max_pc_7d_min', 'max_pc_7d_max', 'max_pc_7d_std', 'max_pc_7d_var', 'max_pc_7d_p25', 'max_pc_7d_p50', 'max_pc_7d_p75']
# ['max_pc_7d_p90', 'max_pc_7d_p95', 'max_pc_30d_mean', 'max_pc_30d_min', 'max_pc_30d_max', 'max_pc_30d_std', 'max_pc_30d_var', 'max_pc_30d_p25', 'max_pc_30d_p50', 'max_pc_30d_p75']
# ['max_pc_30d_p90', 'max_pc_30d_p95', 'total_pd_2d_mean', 'total_pd_2d_min', 'total_pd_2d_max', 'total_pd_2d_std', 'total_pd_2d_var', 'total_pd_2d_p25', 'total_pd_2d_p50', 'total_pd_2d_p75']
# ['total_pd_2d_p90', 'total_pd_2d_p95', 'total_pd_3d_mean', 'total_pd_3d_min', 'total_pd_3d_max', 'total_pd_3d_std', 'total_pd_3d_var', 'total_pd_3d_p25', 'total_pd_3d_p50', 'total_pd_3d_p75']
# ['total_pd_3d_p90', 'total_pd_3d_p95', 'total_pd_7d_mean', 'total_pd_7d_min', 'total_pd_7d_max', 'total_pd_7d_std', 'total_pd_7d_var', 'total_pd_7d_p25', 'total_pd_7d_p50', 'total_pd_7d_p75']
# ['total_pd_7d_p90', 'total_pd_7d_p95', 'total_pd_30d_mean', 'total_pd_30d_min', 'total_pd_30d_max', 'total_pd_30d_std', 'total_pd_30d_var', 'total_pd_30d_p25', 'total_pd_30d_p50', 'total_pd_30d_p75']
# ['total_pd_30d_p90', 'total_pd_30d_p95', 'avg_pd_2d_mean', 'avg_pd_2d_min', 'avg_pd_2d_max', 'avg_pd_2d_std', 'avg_pd_2d_var', 'avg_pd_2d_p25', 'avg_pd_2d_p50', 'avg_pd_2d_p75']
# ['avg_pd_2d_p90', 'avg_pd_2d_p95', 'avg_pd_3d_mean', 'avg_pd_3d_min', 'avg_pd_3d_max', 'avg_pd_3d_std', 'avg_pd_3d_var', 'avg_pd_3d_p25', 'avg_pd_3d_p50', 'avg_pd_3d_p75']
# ['avg_pd_3d_p90', 'avg_pd_3d_p95', 'avg_pd_7d_mean', 'avg_pd_7d_min', 'avg_pd_7d_max', 'avg_pd_7d_std', 'avg_pd_7d_var', 'avg_pd_7d_p25', 'avg_pd_7d_p50', 'avg_pd_7d_p75']
# ['avg_pd_7d_p90', 'avg_pd_7d_p95', 'avg_pd_30d_mean', 'avg_pd_30d_min', 'avg_pd_30d_max', 'avg_pd_30d_std', 'avg_pd_30d_var', 'avg_pd_30d_p25', 'avg_pd_30d_p50', 'avg_pd_30d_p75']
# ['avg_pd_30d_p90', 'avg_pd_30d_p95', 'min_pd_2d_mean', 'min_pd_2d_min', 'min_pd_2d_max', 'min_pd_2d_std', 'min_pd_2d_var', 'min_pd_2d_p25', 'min_pd_2d_p50', 'min_pd_2d_p75']
# ['min_pd_2d_p90', 'min_pd_2d_p95', 'min_pd_3d_mean', 'min_pd_3d_min', 'min_pd_3d_max', 'min_pd_3d_std', 'min_pd_3d_var', 'min_pd_3d_p25', 'min_pd_3d_p50', 'min_pd_3d_p75']
# ['min_pd_3d_p90', 'min_pd_3d_p95', 'min_pd_7d_mean', 'min_pd_7d_min', 'min_pd_7d_max', 'min_pd_7d_std', 'min_pd_7d_var', 'min_pd_7d_p25', 'min_pd_7d_p50', 'min_pd_7d_p75']
# ['min_pd_7d_p90', 'min_pd_7d_p95', 'min_pd_30d_mean', 'min_pd_30d_min', 'min_pd_30d_max', 'min_pd_30d_std', 'min_pd_30d_var', 'min_pd_30d_p25', 'min_pd_30d_p50', 'min_pd_30d_p75']
# ['min_pd_30d_p90', 'min_pd_30d_p95', 'max_pd_2d_mean', 'max_pd_2d_min', 'max_pd_2d_max', 'max_pd_2d_std', 'max_pd_2d_var', 'max_pd_2d_p25', 'max_pd_2d_p50', 'max_pd_2d_p75']
# ['max_pd_2d_p90', 'max_pd_2d_p95', 'max_pd_3d_mean', 'max_pd_3d_min', 'max_pd_3d_max', 'max_pd_3d_std', 'max_pd_3d_var', 'max_pd_3d_p25', 'max_pd_3d_p50', 'max_pd_3d_p75']
# ['max_pd_3d_p90', 'max_pd_3d_p95', 'max_pd_7d_mean', 'max_pd_7d_min', 'max_pd_7d_max', 'max_pd_7d_std', 'max_pd_7d_var', 'max_pd_7d_p25', 'max_pd_7d_p50', 'max_pd_7d_p75']
# ['max_pd_7d_p90', 'max_pd_7d_p95', 'max_pd_30d_mean', 'max_pd_30d_min', 'max_pd_30d_max', 'max_pd_30d_std', 'max_pd_30d_var', 'max_pd_30d_p25', 'max_pd_30d_p50', 'max_pd_30d_p75']
# ['max_pd_30d_p90', 'max_pd_30d_p95', 'total_pp_2d_mean', 'total_pp_2d_min', 'total_pp_2d_max', 'total_pp_2d_std', 'total_pp_2d_var', 'total_pp_2d_p25', 'total_pp_2d_p50', 'total_pp_2d_p75']
# ['total_pp_2d_p90', 'total_pp_2d_p95', 'total_pp_3d_mean', 'total_pp_3d_min', 'total_pp_3d_max', 'total_pp_3d_std', 'total_pp_3d_var', 'total_pp_3d_p25', 'total_pp_3d_p50', 'total_pp_3d_p75']
# ['total_pp_3d_p90', 'total_pp_3d_p95', 'total_pp_7d_mean', 'total_pp_7d_min', 'total_pp_7d_max', 'total_pp_7d_std', 'total_pp_7d_var', 'total_pp_7d_p25', 'total_pp_7d_p50', 'total_pp_7d_p75']
# ['total_pp_7d_p90', 'total_pp_7d_p95', 'total_pp_30d_mean', 'total_pp_30d_min', 'total_pp_30d_max', 'total_pp_30d_std', 'total_pp_30d_var', 'total_pp_30d_p25', 'total_pp_30d_p50', 'total_pp_30d_p75']
# ['total_pp_30d_p90', 'total_pp_30d_p95', 'avg_pp_2d_mean', 'avg_pp_2d_min', 'avg_pp_2d_max', 'avg_pp_2d_std', 'avg_pp_2d_var', 'avg_pp_2d_p25', 'avg_pp_2d_p50', 'avg_pp_2d_p75']
# ['avg_pp_2d_p90', 'avg_pp_2d_p95', 'avg_pp_3d_mean', 'avg_pp_3d_min', 'avg_pp_3d_max', 'avg_pp_3d_std', 'avg_pp_3d_var', 'avg_pp_3d_p25', 'avg_pp_3d_p50', 'avg_pp_3d_p75']
# ['avg_pp_3d_p90', 'avg_pp_3d_p95', 'avg_pp_7d_mean', 'avg_pp_7d_min', 'avg_pp_7d_max', 'avg_pp_7d_std', 'avg_pp_7d_var', 'avg_pp_7d_p25', 'avg_pp_7d_p50', 'avg_pp_7d_p75']
# ['avg_pp_7d_p90', 'avg_pp_7d_p95', 'avg_pp_30d_mean', 'avg_pp_30d_min', 'avg_pp_30d_max', 'avg_pp_30d_std', 'avg_pp_30d_var', 'avg_pp_30d_p25', 'avg_pp_30d_p50', 'avg_pp_30d_p75']
# ['avg_pp_30d_p90', 'avg_pp_30d_p95', 'min_pp_2d_mean', 'min_pp_2d_min', 'min_pp_2d_max', 'min_pp_2d_std', 'min_pp_2d_var', 'min_pp_2d_p25', 'min_pp_2d_p50', 'min_pp_2d_p75']
# ['min_pp_2d_p90', 'min_pp_2d_p95', 'min_pp_3d_mean', 'min_pp_3d_min', 'min_pp_3d_max', 'min_pp_3d_std', 'min_pp_3d_var', 'min_pp_3d_p25', 'min_pp_3d_p50', 'min_pp_3d_p75']
# ['min_pp_3d_p90', 'min_pp_3d_p95', 'min_pp_7d_mean', 'min_pp_7d_min', 'min_pp_7d_max', 'min_pp_7d_std', 'min_pp_7d_var', 'min_pp_7d_p25', 'min_pp_7d_p50', 'min_pp_7d_p75']
# ['min_pp_7d_p90', 'min_pp_7d_p95', 'min_pp_30d_mean', 'min_pp_30d_min', 'min_pp_30d_max', 'min_pp_30d_std', 'min_pp_30d_var', 'min_pp_30d_p25', 'min_pp_30d_p50', 'min_pp_30d_p75']
# ['min_pp_30d_p90', 'min_pp_30d_p95', 'max_pp_2d_mean', 'max_pp_2d_min', 'max_pp_2d_max', 'max_pp_2d_std', 'max_pp_2d_var', 'max_pp_2d_p25', 'max_pp_2d_p50', 'max_pp_2d_p75']
# ['max_pp_2d_p90', 'max_pp_2d_p95', 'max_pp_3d_mean', 'max_pp_3d_min', 'max_pp_3d_max', 'max_pp_3d_std', 'max_pp_3d_var', 'max_pp_3d_p25', 'max_pp_3d_p50', 'max_pp_3d_p75']
# ['max_pp_3d_p90', 'max_pp_3d_p95', 'max_pp_7d_mean', 'max_pp_7d_min', 'max_pp_7d_max', 'max_pp_7d_std', 'max_pp_7d_var', 'max_pp_7d_p25', 'max_pp_7d_p50', 'max_pp_7d_p75']
# ['max_pp_7d_p90', 'max_pp_7d_p95', 'max_pp_30d_mean', 'max_pp_30d_min', 'max_pp_30d_max', 'max_pp_30d_std', 'max_pp_30d_var', 'max_pp_30d_p25', 'max_pp_30d_p50', 'max_pp_30d_p75']
# ['max_pp_30d_p90', 'max_pp_30d_p95']

# %%
cpd.rename({'mode_product_id':'product_id'},axis=1 , inplace=True)

# %%
columns = cpd.columns

print("=" * 100)
print(f"Total columns: {(cpd.shape)}")
print("=" * 10)
for i in range(0, len(columns), 10):
    print(columns[i:i+10].tolist())
# Out:
# ====================================================================================================
# Total columns: (27, 1032)
# ==========
# ['customer_id', 'order_date', 'purchase_count', 'avg_quantity', 'max_quantity', 'p25_quantity', 'p50_quantity', 'p75_quantity', 'p90_quantity', 'p95_quantity']
# ['total_spend', 'avg_spend', 'min_spend', 'max_spend', 'p25_spend', 'p50_spend', 'p75_spend', 'p90_spend', 'p95_spend', 'total_pad']
# ['avg_pad', 'min_pad', 'max_pad', 'p25_pad', 'p50_pad', 'p75_pad', 'p90_pad', 'p95_pad', 'total_pc', 'avg_pc']
# ['min_pc', 'max_pc', 'p25_pc', 'p50_pc', 'p75_pc', 'p90_pc', 'p95_pc', 'total_pd', 'avg_pd', 'min_pd']
# ['max_pd', 'p25_pd', 'p50_pd', 'p75_pd', 'p90_pd', 'p95_pd', 'total_pp', 'avg_pp', 'min_pp', 'max_pp']
# ['p25_pp', 'p50_pp', 'p75_pp', 'p90_pp', 'p95_pp', 'product_id', 'last_order_date', 'last_purchase_count', 'last_avg_quantity', 'last_max_quantity']
# ['last_p25_quantity', 'last_p50_quantity', 'last_p75_quantity', 'last_p90_quantity', 'last_p95_quantity', 'last_total_spend', 'last_avg_spend', 'last_min_spend', 'last_max_spend', 'last_p25_spend']
# ['last_p50_spend', 'last_p75_spend', 'last_p90_spend', 'last_p95_spend', 'last_total_pad', 'last_avg_pad', 'last_min_pad', 'last_max_pad', 'last_p25_pad', 'last_p50_pad']
# ['last_p75_pad', 'last_p90_pad', 'last_p95_pad', 'last_total_pc', 'last_avg_pc', 'last_min_pc', 'last_max_pc', 'last_p25_pc', 'last_p50_pc', 'last_p75_pc']
# ['last_p90_pc', 'last_p95_pc', 'last_total_pd', 'last_avg_pd', 'last_min_pd', 'last_max_pd', 'last_p25_pd', 'last_p50_pd', 'last_p75_pd', 'last_p90_pd']
# ['last_p95_pd', 'last_total_pp', 'last_avg_pp', 'last_min_pp', 'last_max_pp', 'last_p25_pp', 'last_p50_pp', 'last_p75_pp', 'last_p90_pp', 'last_p95_pp']
# ['Same_order', 'Last_transaction_days', 'purchase_count_2d_mean', 'purchase_count_2d_min', 'purchase_count_2d_max', 'purchase_count_2d_std', 'purchase_count_2d_var', 'purchase_count_2d_p25', 'purchase_count_2d_p50', 'purchase_count_2d_p75']
# ['purchase_count_2d_p90', 'purchase_count_2d_p95', 'purchase_count_3d_mean', 'purchase_count_3d_min', 'purchase_count_3d_max', 'purchase_count_3d_std', 'purchase_count_3d_var', 'purchase_count_3d_p25', 'purchase_count_3d_p50', 'purchase_count_3d_p75']
# ['purchase_count_3d_p90', 'purchase_count_3d_p95', 'purchase_count_7d_mean', 'purchase_count_7d_min', 'purchase_count_7d_max', 'purchase_count_7d_std', 'purchase_count_7d_var', 'purchase_count_7d_p25', 'purchase_count_7d_p50', 'purchase_count_7d_p75']
# ['purchase_count_7d_p90', 'purchase_count_7d_p95', 'purchase_count_30d_mean', 'purchase_count_30d_min', 'purchase_count_30d_max', 'purchase_count_30d_std', 'purchase_count_30d_var', 'purchase_count_30d_p25', 'purchase_count_30d_p50', 'purchase_count_30d_p75']
# ['purchase_count_30d_p90', 'purchase_count_30d_p95', 'avg_quantity_2d_mean', 'avg_quantity_2d_min', 'avg_quantity_2d_max', 'avg_quantity_2d_std', 'avg_quantity_2d_var', 'avg_quantity_2d_p25', 'avg_quantity_2d_p50', 'avg_quantity_2d_p75']
# ['avg_quantity_2d_p90', 'avg_quantity_2d_p95', 'avg_quantity_3d_mean', 'avg_quantity_3d_min', 'avg_quantity_3d_max', 'avg_quantity_3d_std', 'avg_quantity_3d_var', 'avg_quantity_3d_p25', 'avg_quantity_3d_p50', 'avg_quantity_3d_p75']
# ['avg_quantity_3d_p90', 'avg_quantity_3d_p95', 'avg_quantity_7d_mean', 'avg_quantity_7d_min', 'avg_quantity_7d_max', 'avg_quantity_7d_std', 'avg_quantity_7d_var', 'avg_quantity_7d_p25', 'avg_quantity_7d_p50', 'avg_quantity_7d_p75']
# ['avg_quantity_7d_p90', 'avg_quantity_7d_p95', 'avg_quantity_30d_mean', 'avg_quantity_30d_min', 'avg_quantity_30d_max', 'avg_quantity_30d_std', 'avg_quantity_30d_var', 'avg_quantity_30d_p25', 'avg_quantity_30d_p50', 'avg_quantity_30d_p75']
# ['avg_quantity_30d_p90', 'avg_quantity_30d_p95', 'max_quantity_2d_mean', 'max_quantity_2d_min', 'max_quantity_2d_max', 'max_quantity_2d_std', 'max_quantity_2d_var', 'max_quantity_2d_p25', 'max_quantity_2d_p50', 'max_quantity_2d_p75']
# ['max_quantity_2d_p90', 'max_quantity_2d_p95', 'max_quantity_3d_mean', 'max_quantity_3d_min', 'max_quantity_3d_max', 'max_quantity_3d_std', 'max_quantity_3d_var', 'max_quantity_3d_p25', 'max_quantity_3d_p50', 'max_quantity_3d_p75']
# ['max_quantity_3d_p90', 'max_quantity_3d_p95', 'max_quantity_7d_mean', 'max_quantity_7d_min', 'max_quantity_7d_max', 'max_quantity_7d_std', 'max_quantity_7d_var', 'max_quantity_7d_p25', 'max_quantity_7d_p50', 'max_quantity_7d_p75']
# ['max_quantity_7d_p90', 'max_quantity_7d_p95', 'max_quantity_30d_mean', 'max_quantity_30d_min', 'max_quantity_30d_max', 'max_quantity_30d_std', 'max_quantity_30d_var', 'max_quantity_30d_p25', 'max_quantity_30d_p50', 'max_quantity_30d_p75']
# ['max_quantity_30d_p90', 'max_quantity_30d_p95', 'total_spend_2d_mean', 'total_spend_2d_min', 'total_spend_2d_max', 'total_spend_2d_std', 'total_spend_2d_var', 'total_spend_2d_p25', 'total_spend_2d_p50', 'total_spend_2d_p75']
# ['total_spend_2d_p90', 'total_spend_2d_p95', 'total_spend_3d_mean', 'total_spend_3d_min', 'total_spend_3d_max', 'total_spend_3d_std', 'total_spend_3d_var', 'total_spend_3d_p25', 'total_spend_3d_p50', 'total_spend_3d_p75']
# ['total_spend_3d_p90', 'total_spend_3d_p95', 'total_spend_7d_mean', 'total_spend_7d_min', 'total_spend_7d_max', 'total_spend_7d_std', 'total_spend_7d_var', 'total_spend_7d_p25', 'total_spend_7d_p50', 'total_spend_7d_p75']
# ['total_spend_7d_p90', 'total_spend_7d_p95', 'total_spend_30d_mean', 'total_spend_30d_min', 'total_spend_30d_max', 'total_spend_30d_std', 'total_spend_30d_var', 'total_spend_30d_p25', 'total_spend_30d_p50', 'total_spend_30d_p75']
# ['total_spend_30d_p90', 'total_spend_30d_p95', 'avg_spend_2d_mean', 'avg_spend_2d_min', 'avg_spend_2d_max', 'avg_spend_2d_std', 'avg_spend_2d_var', 'avg_spend_2d_p25', 'avg_spend_2d_p50', 'avg_spend_2d_p75']
# ['avg_spend_2d_p90', 'avg_spend_2d_p95', 'avg_spend_3d_mean', 'avg_spend_3d_min', 'avg_spend_3d_max', 'avg_spend_3d_std', 'avg_spend_3d_var', 'avg_spend_3d_p25', 'avg_spend_3d_p50', 'avg_spend_3d_p75']
# ['avg_spend_3d_p90', 'avg_spend_3d_p95', 'avg_spend_7d_mean', 'avg_spend_7d_min', 'avg_spend_7d_max', 'avg_spend_7d_std', 'avg_spend_7d_var', 'avg_spend_7d_p25', 'avg_spend_7d_p50', 'avg_spend_7d_p75']
# ['avg_spend_7d_p90', 'avg_spend_7d_p95', 'avg_spend_30d_mean', 'avg_spend_30d_min', 'avg_spend_30d_max', 'avg_spend_30d_std', 'avg_spend_30d_var', 'avg_spend_30d_p25', 'avg_spend_30d_p50', 'avg_spend_30d_p75']
# ['avg_spend_30d_p90', 'avg_spend_30d_p95', 'min_spend_2d_mean', 'min_spend_2d_min', 'min_spend_2d_max', 'min_spend_2d_std', 'min_spend_2d_var', 'min_spend_2d_p25', 'min_spend_2d_p50', 'min_spend_2d_p75']
# ['min_spend_2d_p90', 'min_spend_2d_p95', 'min_spend_3d_mean', 'min_spend_3d_min', 'min_spend_3d_max', 'min_spend_3d_std', 'min_spend_3d_var', 'min_spend_3d_p25', 'min_spend_3d_p50', 'min_spend_3d_p75']
# ['min_spend_3d_p90', 'min_spend_3d_p95', 'min_spend_7d_mean', 'min_spend_7d_min', 'min_spend_7d_max', 'min_spend_7d_std', 'min_spend_7d_var', 'min_spend_7d_p25', 'min_spend_7d_p50', 'min_spend_7d_p75']
# ['min_spend_7d_p90', 'min_spend_7d_p95', 'min_spend_30d_mean', 'min_spend_30d_min', 'min_spend_30d_max', 'min_spend_30d_std', 'min_spend_30d_var', 'min_spend_30d_p25', 'min_spend_30d_p50', 'min_spend_30d_p75']
# ['min_spend_30d_p90', 'min_spend_30d_p95', 'max_spend_2d_mean', 'max_spend_2d_min', 'max_spend_2d_max', 'max_spend_2d_std', 'max_spend_2d_var', 'max_spend_2d_p25', 'max_spend_2d_p50', 'max_spend_2d_p75']
# ['max_spend_2d_p90', 'max_spend_2d_p95', 'max_spend_3d_mean', 'max_spend_3d_min', 'max_spend_3d_max', 'max_spend_3d_std', 'max_spend_3d_var', 'max_spend_3d_p25', 'max_spend_3d_p50', 'max_spend_3d_p75']
# ['max_spend_3d_p90', 'max_spend_3d_p95', 'max_spend_7d_mean', 'max_spend_7d_min', 'max_spend_7d_max', 'max_spend_7d_std', 'max_spend_7d_var', 'max_spend_7d_p25', 'max_spend_7d_p50', 'max_spend_7d_p75']
# ['max_spend_7d_p90', 'max_spend_7d_p95', 'max_spend_30d_mean', 'max_spend_30d_min', 'max_spend_30d_max', 'max_spend_30d_std', 'max_spend_30d_var', 'max_spend_30d_p25', 'max_spend_30d_p50', 'max_spend_30d_p75']
# ['max_spend_30d_p90', 'max_spend_30d_p95', 'total_pad_2d_mean', 'total_pad_2d_min', 'total_pad_2d_max', 'total_pad_2d_std', 'total_pad_2d_var', 'total_pad_2d_p25', 'total_pad_2d_p50', 'total_pad_2d_p75']
# ['total_pad_2d_p90', 'total_pad_2d_p95', 'total_pad_3d_mean', 'total_pad_3d_min', 'total_pad_3d_max', 'total_pad_3d_std', 'total_pad_3d_var', 'total_pad_3d_p25', 'total_pad_3d_p50', 'total_pad_3d_p75']
# ['total_pad_3d_p90', 'total_pad_3d_p95', 'total_pad_7d_mean', 'total_pad_7d_min', 'total_pad_7d_max', 'total_pad_7d_std', 'total_pad_7d_var', 'total_pad_7d_p25', 'total_pad_7d_p50', 'total_pad_7d_p75']
# ['total_pad_7d_p90', 'total_pad_7d_p95', 'total_pad_30d_mean', 'total_pad_30d_min', 'total_pad_30d_max', 'total_pad_30d_std', 'total_pad_30d_var', 'total_pad_30d_p25', 'total_pad_30d_p50', 'total_pad_30d_p75']
# ['total_pad_30d_p90', 'total_pad_30d_p95', 'avg_pad_2d_mean', 'avg_pad_2d_min', 'avg_pad_2d_max', 'avg_pad_2d_std', 'avg_pad_2d_var', 'avg_pad_2d_p25', 'avg_pad_2d_p50', 'avg_pad_2d_p75']
# ['avg_pad_2d_p90', 'avg_pad_2d_p95', 'avg_pad_3d_mean', 'avg_pad_3d_min', 'avg_pad_3d_max', 'avg_pad_3d_std', 'avg_pad_3d_var', 'avg_pad_3d_p25', 'avg_pad_3d_p50', 'avg_pad_3d_p75']
# ['avg_pad_3d_p90', 'avg_pad_3d_p95', 'avg_pad_7d_mean', 'avg_pad_7d_min', 'avg_pad_7d_max', 'avg_pad_7d_std', 'avg_pad_7d_var', 'avg_pad_7d_p25', 'avg_pad_7d_p50', 'avg_pad_7d_p75']
# ['avg_pad_7d_p90', 'avg_pad_7d_p95', 'avg_pad_30d_mean', 'avg_pad_30d_min', 'avg_pad_30d_max', 'avg_pad_30d_std', 'avg_pad_30d_var', 'avg_pad_30d_p25', 'avg_pad_30d_p50', 'avg_pad_30d_p75']
# ['avg_pad_30d_p90', 'avg_pad_30d_p95', 'min_pad_2d_mean', 'min_pad_2d_min', 'min_pad_2d_max', 'min_pad_2d_std', 'min_pad_2d_var', 'min_pad_2d_p25', 'min_pad_2d_p50', 'min_pad_2d_p75']
# ['min_pad_2d_p90', 'min_pad_2d_p95', 'min_pad_3d_mean', 'min_pad_3d_min', 'min_pad_3d_max', 'min_pad_3d_std', 'min_pad_3d_var', 'min_pad_3d_p25', 'min_pad_3d_p50', 'min_pad_3d_p75']
# ['min_pad_3d_p90', 'min_pad_3d_p95', 'min_pad_7d_mean', 'min_pad_7d_min', 'min_pad_7d_max', 'min_pad_7d_std', 'min_pad_7d_var', 'min_pad_7d_p25', 'min_pad_7d_p50', 'min_pad_7d_p75']
# ['min_pad_7d_p90', 'min_pad_7d_p95', 'min_pad_30d_mean', 'min_pad_30d_min', 'min_pad_30d_max', 'min_pad_30d_std', 'min_pad_30d_var', 'min_pad_30d_p25', 'min_pad_30d_p50', 'min_pad_30d_p75']
# ['min_pad_30d_p90', 'min_pad_30d_p95', 'max_pad_2d_mean', 'max_pad_2d_min', 'max_pad_2d_max', 'max_pad_2d_std', 'max_pad_2d_var', 'max_pad_2d_p25', 'max_pad_2d_p50', 'max_pad_2d_p75']
# ['max_pad_2d_p90', 'max_pad_2d_p95', 'max_pad_3d_mean', 'max_pad_3d_min', 'max_pad_3d_max', 'max_pad_3d_std', 'max_pad_3d_var', 'max_pad_3d_p25', 'max_pad_3d_p50', 'max_pad_3d_p75']
# ['max_pad_3d_p90', 'max_pad_3d_p95', 'max_pad_7d_mean', 'max_pad_7d_min', 'max_pad_7d_max', 'max_pad_7d_std', 'max_pad_7d_var', 'max_pad_7d_p25', 'max_pad_7d_p50', 'max_pad_7d_p75']
# ['max_pad_7d_p90', 'max_pad_7d_p95', 'max_pad_30d_mean', 'max_pad_30d_min', 'max_pad_30d_max', 'max_pad_30d_std', 'max_pad_30d_var', 'max_pad_30d_p25', 'max_pad_30d_p50', 'max_pad_30d_p75']
# ['max_pad_30d_p90', 'max_pad_30d_p95', 'total_pc_2d_mean', 'total_pc_2d_min', 'total_pc_2d_max', 'total_pc_2d_std', 'total_pc_2d_var', 'total_pc_2d_p25', 'total_pc_2d_p50', 'total_pc_2d_p75']
# ['total_pc_2d_p90', 'total_pc_2d_p95', 'total_pc_3d_mean', 'total_pc_3d_min', 'total_pc_3d_max', 'total_pc_3d_std', 'total_pc_3d_var', 'total_pc_3d_p25', 'total_pc_3d_p50', 'total_pc_3d_p75']
# ['total_pc_3d_p90', 'total_pc_3d_p95', 'total_pc_7d_mean', 'total_pc_7d_min', 'total_pc_7d_max', 'total_pc_7d_std', 'total_pc_7d_var', 'total_pc_7d_p25', 'total_pc_7d_p50', 'total_pc_7d_p75']
# ['total_pc_7d_p90', 'total_pc_7d_p95', 'total_pc_30d_mean', 'total_pc_30d_min', 'total_pc_30d_max', 'total_pc_30d_std', 'total_pc_30d_var', 'total_pc_30d_p25', 'total_pc_30d_p50', 'total_pc_30d_p75']
# ['total_pc_30d_p90', 'total_pc_30d_p95', 'avg_pc_2d_mean', 'avg_pc_2d_min', 'avg_pc_2d_max', 'avg_pc_2d_std', 'avg_pc_2d_var', 'avg_pc_2d_p25', 'avg_pc_2d_p50', 'avg_pc_2d_p75']
# ['avg_pc_2d_p90', 'avg_pc_2d_p95', 'avg_pc_3d_mean', 'avg_pc_3d_min', 'avg_pc_3d_max', 'avg_pc_3d_std', 'avg_pc_3d_var', 'avg_pc_3d_p25', 'avg_pc_3d_p50', 'avg_pc_3d_p75']
# ['avg_pc_3d_p90', 'avg_pc_3d_p95', 'avg_pc_7d_mean', 'avg_pc_7d_min', 'avg_pc_7d_max', 'avg_pc_7d_std', 'avg_pc_7d_var', 'avg_pc_7d_p25', 'avg_pc_7d_p50', 'avg_pc_7d_p75']
# ['avg_pc_7d_p90', 'avg_pc_7d_p95', 'avg_pc_30d_mean', 'avg_pc_30d_min', 'avg_pc_30d_max', 'avg_pc_30d_std', 'avg_pc_30d_var', 'avg_pc_30d_p25', 'avg_pc_30d_p50', 'avg_pc_30d_p75']
# ['avg_pc_30d_p90', 'avg_pc_30d_p95', 'min_pc_2d_mean', 'min_pc_2d_min', 'min_pc_2d_max', 'min_pc_2d_std', 'min_pc_2d_var', 'min_pc_2d_p25', 'min_pc_2d_p50', 'min_pc_2d_p75']
# ['min_pc_2d_p90', 'min_pc_2d_p95', 'min_pc_3d_mean', 'min_pc_3d_min', 'min_pc_3d_max', 'min_pc_3d_std', 'min_pc_3d_var', 'min_pc_3d_p25', 'min_pc_3d_p50', 'min_pc_3d_p75']
# ['min_pc_3d_p90', 'min_pc_3d_p95', 'min_pc_7d_mean', 'min_pc_7d_min', 'min_pc_7d_max', 'min_pc_7d_std', 'min_pc_7d_var', 'min_pc_7d_p25', 'min_pc_7d_p50', 'min_pc_7d_p75']
# ['min_pc_7d_p90', 'min_pc_7d_p95', 'min_pc_30d_mean', 'min_pc_30d_min', 'min_pc_30d_max', 'min_pc_30d_std', 'min_pc_30d_var', 'min_pc_30d_p25', 'min_pc_30d_p50', 'min_pc_30d_p75']
# ['min_pc_30d_p90', 'min_pc_30d_p95', 'max_pc_2d_mean', 'max_pc_2d_min', 'max_pc_2d_max', 'max_pc_2d_std', 'max_pc_2d_var', 'max_pc_2d_p25', 'max_pc_2d_p50', 'max_pc_2d_p75']
# ['max_pc_2d_p90', 'max_pc_2d_p95', 'max_pc_3d_mean', 'max_pc_3d_min', 'max_pc_3d_max', 'max_pc_3d_std', 'max_pc_3d_var', 'max_pc_3d_p25', 'max_pc_3d_p50', 'max_pc_3d_p75']
# ['max_pc_3d_p90', 'max_pc_3d_p95', 'max_pc_7d_mean', 'max_pc_7d_min', 'max_pc_7d_max', 'max_pc_7d_std', 'max_pc_7d_var', 'max_pc_7d_p25', 'max_pc_7d_p50', 'max_pc_7d_p75']
# ['max_pc_7d_p90', 'max_pc_7d_p95', 'max_pc_30d_mean', 'max_pc_30d_min', 'max_pc_30d_max', 'max_pc_30d_std', 'max_pc_30d_var', 'max_pc_30d_p25', 'max_pc_30d_p50', 'max_pc_30d_p75']
# ['max_pc_30d_p90', 'max_pc_30d_p95', 'total_pd_2d_mean', 'total_pd_2d_min', 'total_pd_2d_max', 'total_pd_2d_std', 'total_pd_2d_var', 'total_pd_2d_p25', 'total_pd_2d_p50', 'total_pd_2d_p75']
# ['total_pd_2d_p90', 'total_pd_2d_p95', 'total_pd_3d_mean', 'total_pd_3d_min', 'total_pd_3d_max', 'total_pd_3d_std', 'total_pd_3d_var', 'total_pd_3d_p25', 'total_pd_3d_p50', 'total_pd_3d_p75']
# ['total_pd_3d_p90', 'total_pd_3d_p95', 'total_pd_7d_mean', 'total_pd_7d_min', 'total_pd_7d_max', 'total_pd_7d_std', 'total_pd_7d_var', 'total_pd_7d_p25', 'total_pd_7d_p50', 'total_pd_7d_p75']
# ['total_pd_7d_p90', 'total_pd_7d_p95', 'total_pd_30d_mean', 'total_pd_30d_min', 'total_pd_30d_max', 'total_pd_30d_std', 'total_pd_30d_var', 'total_pd_30d_p25', 'total_pd_30d_p50', 'total_pd_30d_p75']
# ['total_pd_30d_p90', 'total_pd_30d_p95', 'avg_pd_2d_mean', 'avg_pd_2d_min', 'avg_pd_2d_max', 'avg_pd_2d_std', 'avg_pd_2d_var', 'avg_pd_2d_p25', 'avg_pd_2d_p50', 'avg_pd_2d_p75']
# ['avg_pd_2d_p90', 'avg_pd_2d_p95', 'avg_pd_3d_mean', 'avg_pd_3d_min', 'avg_pd_3d_max', 'avg_pd_3d_std', 'avg_pd_3d_var', 'avg_pd_3d_p25', 'avg_pd_3d_p50', 'avg_pd_3d_p75']
# ['avg_pd_3d_p90', 'avg_pd_3d_p95', 'avg_pd_7d_mean', 'avg_pd_7d_min', 'avg_pd_7d_max', 'avg_pd_7d_std', 'avg_pd_7d_var', 'avg_pd_7d_p25', 'avg_pd_7d_p50', 'avg_pd_7d_p75']
# ['avg_pd_7d_p90', 'avg_pd_7d_p95', 'avg_pd_30d_mean', 'avg_pd_30d_min', 'avg_pd_30d_max', 'avg_pd_30d_std', 'avg_pd_30d_var', 'avg_pd_30d_p25', 'avg_pd_30d_p50', 'avg_pd_30d_p75']
# ['avg_pd_30d_p90', 'avg_pd_30d_p95', 'min_pd_2d_mean', 'min_pd_2d_min', 'min_pd_2d_max', 'min_pd_2d_std', 'min_pd_2d_var', 'min_pd_2d_p25', 'min_pd_2d_p50', 'min_pd_2d_p75']
# ['min_pd_2d_p90', 'min_pd_2d_p95', 'min_pd_3d_mean', 'min_pd_3d_min', 'min_pd_3d_max', 'min_pd_3d_std', 'min_pd_3d_var', 'min_pd_3d_p25', 'min_pd_3d_p50', 'min_pd_3d_p75']
# ['min_pd_3d_p90', 'min_pd_3d_p95', 'min_pd_7d_mean', 'min_pd_7d_min', 'min_pd_7d_max', 'min_pd_7d_std', 'min_pd_7d_var', 'min_pd_7d_p25', 'min_pd_7d_p50', 'min_pd_7d_p75']
# ['min_pd_7d_p90', 'min_pd_7d_p95', 'min_pd_30d_mean', 'min_pd_30d_min', 'min_pd_30d_max', 'min_pd_30d_std', 'min_pd_30d_var', 'min_pd_30d_p25', 'min_pd_30d_p50', 'min_pd_30d_p75']
# ['min_pd_30d_p90', 'min_pd_30d_p95', 'max_pd_2d_mean', 'max_pd_2d_min', 'max_pd_2d_max', 'max_pd_2d_std', 'max_pd_2d_var', 'max_pd_2d_p25', 'max_pd_2d_p50', 'max_pd_2d_p75']
# ['max_pd_2d_p90', 'max_pd_2d_p95', 'max_pd_3d_mean', 'max_pd_3d_min', 'max_pd_3d_max', 'max_pd_3d_std', 'max_pd_3d_var', 'max_pd_3d_p25', 'max_pd_3d_p50', 'max_pd_3d_p75']
# ['max_pd_3d_p90', 'max_pd_3d_p95', 'max_pd_7d_mean', 'max_pd_7d_min', 'max_pd_7d_max', 'max_pd_7d_std', 'max_pd_7d_var', 'max_pd_7d_p25', 'max_pd_7d_p50', 'max_pd_7d_p75']
# ['max_pd_7d_p90', 'max_pd_7d_p95', 'max_pd_30d_mean', 'max_pd_30d_min', 'max_pd_30d_max', 'max_pd_30d_std', 'max_pd_30d_var', 'max_pd_30d_p25', 'max_pd_30d_p50', 'max_pd_30d_p75']
# ['max_pd_30d_p90', 'max_pd_30d_p95', 'total_pp_2d_mean', 'total_pp_2d_min', 'total_pp_2d_max', 'total_pp_2d_std', 'total_pp_2d_var', 'total_pp_2d_p25', 'total_pp_2d_p50', 'total_pp_2d_p75']
# ['total_pp_2d_p90', 'total_pp_2d_p95', 'total_pp_3d_mean', 'total_pp_3d_min', 'total_pp_3d_max', 'total_pp_3d_std', 'total_pp_3d_var', 'total_pp_3d_p25', 'total_pp_3d_p50', 'total_pp_3d_p75']
# ['total_pp_3d_p90', 'total_pp_3d_p95', 'total_pp_7d_mean', 'total_pp_7d_min', 'total_pp_7d_max', 'total_pp_7d_std', 'total_pp_7d_var', 'total_pp_7d_p25', 'total_pp_7d_p50', 'total_pp_7d_p75']
# ['total_pp_7d_p90', 'total_pp_7d_p95', 'total_pp_30d_mean', 'total_pp_30d_min', 'total_pp_30d_max', 'total_pp_30d_std', 'total_pp_30d_var', 'total_pp_30d_p25', 'total_pp_30d_p50', 'total_pp_30d_p75']
# ['total_pp_30d_p90', 'total_pp_30d_p95', 'avg_pp_2d_mean', 'avg_pp_2d_min', 'avg_pp_2d_max', 'avg_pp_2d_std', 'avg_pp_2d_var', 'avg_pp_2d_p25', 'avg_pp_2d_p50', 'avg_pp_2d_p75']
# ['avg_pp_2d_p90', 'avg_pp_2d_p95', 'avg_pp_3d_mean', 'avg_pp_3d_min', 'avg_pp_3d_max', 'avg_pp_3d_std', 'avg_pp_3d_var', 'avg_pp_3d_p25', 'avg_pp_3d_p50', 'avg_pp_3d_p75']
# ['avg_pp_3d_p90', 'avg_pp_3d_p95', 'avg_pp_7d_mean', 'avg_pp_7d_min', 'avg_pp_7d_max', 'avg_pp_7d_std', 'avg_pp_7d_var', 'avg_pp_7d_p25', 'avg_pp_7d_p50', 'avg_pp_7d_p75']
# ['avg_pp_7d_p90', 'avg_pp_7d_p95', 'avg_pp_30d_mean', 'avg_pp_30d_min', 'avg_pp_30d_max', 'avg_pp_30d_std', 'avg_pp_30d_var', 'avg_pp_30d_p25', 'avg_pp_30d_p50', 'avg_pp_30d_p75']
# ['avg_pp_30d_p90', 'avg_pp_30d_p95', 'min_pp_2d_mean', 'min_pp_2d_min', 'min_pp_2d_max', 'min_pp_2d_std', 'min_pp_2d_var', 'min_pp_2d_p25', 'min_pp_2d_p50', 'min_pp_2d_p75']
# ['min_pp_2d_p90', 'min_pp_2d_p95', 'min_pp_3d_mean', 'min_pp_3d_min', 'min_pp_3d_max', 'min_pp_3d_std', 'min_pp_3d_var', 'min_pp_3d_p25', 'min_pp_3d_p50', 'min_pp_3d_p75']
# ['min_pp_3d_p90', 'min_pp_3d_p95', 'min_pp_7d_mean', 'min_pp_7d_min', 'min_pp_7d_max', 'min_pp_7d_std', 'min_pp_7d_var', 'min_pp_7d_p25', 'min_pp_7d_p50', 'min_pp_7d_p75']
# ['min_pp_7d_p90', 'min_pp_7d_p95', 'min_pp_30d_mean', 'min_pp_30d_min', 'min_pp_30d_max', 'min_pp_30d_std', 'min_pp_30d_var', 'min_pp_30d_p25', 'min_pp_30d_p50', 'min_pp_30d_p75']
# ['min_pp_30d_p90', 'min_pp_30d_p95', 'max_pp_2d_mean', 'max_pp_2d_min', 'max_pp_2d_max', 'max_pp_2d_std', 'max_pp_2d_var', 'max_pp_2d_p25', 'max_pp_2d_p50', 'max_pp_2d_p75']
# ['max_pp_2d_p90', 'max_pp_2d_p95', 'max_pp_3d_mean', 'max_pp_3d_min', 'max_pp_3d_max', 'max_pp_3d_std', 'max_pp_3d_var', 'max_pp_3d_p25', 'max_pp_3d_p50', 'max_pp_3d_p75']
# ['max_pp_3d_p90', 'max_pp_3d_p95', 'max_pp_7d_mean', 'max_pp_7d_min', 'max_pp_7d_max', 'max_pp_7d_std', 'max_pp_7d_var', 'max_pp_7d_p25', 'max_pp_7d_p50', 'max_pp_7d_p75']
# ['max_pp_7d_p90', 'max_pp_7d_p95', 'max_pp_30d_mean', 'max_pp_30d_min', 'max_pp_30d_max', 'max_pp_30d_std', 'max_pp_30d_var', 'max_pp_30d_p25', 'max_pp_30d_p50', 'max_pp_30d_p75']
# ['max_pp_30d_p90', 'max_pp_30d_p95']
